# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# !rm -rf output/

# %%
! mkdir train
! unzip "/content/drive/MyDrive/Train data/raw_data.zip" -d train
# Out:
# Streaming output truncated to the last 5000 lines.
#   inflating: train/raw_data/0/3394.jpg
#   inflating: train/raw_data/0/3395.jpg
#   inflating: train/raw_data/0/3396.jpg
#   inflating: train/raw_data/0/3397.jpg
#   inflating: train/raw_data/0/3398.jpg
#   inflating: train/raw_data/0/3399.jpg
#   inflating: train/raw_data/0/339.jpg
#   inflating: train/raw_data/0/33.jpg
#   inflating: train/raw_data/0/3400.jpg
#   inflating: train/raw_data/0/3401.jpg
#   inflating: train/raw_data/0/3402.jpg
#   inflating: train/raw_data/0/3403.jpg
#   inflating: train/raw_data/0/3404.jpg
#   inflating: train/raw_data/0/3405.jpg
#   inflating: train/raw_data/0/3406.jpg
#   inflating: train/raw_data/0/3407.jpg
#   inflating: train/raw_data/0/3408.jpg
#   inflating: train/raw_data/0/3409.jpg
#   inflating: train/raw_data/0/340.jpg
#   inflating: train/raw_data/0/3410.jpg
#   inflating: train/raw_data/0/3411.jpg
#   inflating: train/raw_data/0/3412.jpg
#   inflating: train/raw_data/0/3413.jpg
#   inflating: train/raw_data/0/3414.jpg
#   inflating: train/raw_data/0/3415.jpg
#   inflating: train/raw_data/0/3416.jpg
#   inflating: train/raw_data/0/3417.jpg
#   inflating: train/raw_data/0/3418.jpg
#   inflating: train/raw_data/0/3419.jpg
#   inflating: train/raw_data/0/341.jpg
#   inflating: train/raw_data/0/3420.jpg
#   inflating: train/raw_data/0/3421.jpg
#   inflating: train/raw_data/0/3422.jpg
#   inflating: train/raw_data/0/3423.jpg
#   inflating: train/raw_data/0/3424.jpg
#   inflating: train/raw_data/0/3425.jpg
#   inflating: train/raw_data/0/3426.jpg
#   inflating: train/raw_data/0/3427.jpg
#   inflating: train/raw_data/0/3428.jpg
#   inflating: train/raw_data/0/3429.jpg
#   inflating: train/raw_data/0/342.jpg
#   inflating: train/raw_data/0/3430.jpg
#   inflating: train/raw_data/0/3431.jpg
#   inflating: train/raw_data/0/3432.jpg
#   inflating: train/raw_data/0/3433.jpg
#   inflating: train/raw_data/0/3434.jpg
#   inflating: train/raw_data/0/3435.jpg
#   inflating: train/raw_data/0/3436.jpg
#   inflating: train/raw_data/0/3437.jpg
#   inflating: train/raw_data/0/3438.jpg
#   inflating: train/raw_data/0/3439.jpg
#   inflating: train/raw_data/0/343.jpg
#   inflating: train/raw_data/0/3440.jpg
#   inflating: train/raw_data/0/3441.jpg
#   inflating: train/raw_data/0/3442.jpg
#   inflating: train/raw_data/0/3443.jpg
#   inflating: train/raw_data/0/3444.jpg
#   inflating: train/raw_data/0/3445.jpg
#   inflating: train/raw_data/0/3446.jpg
#   inflating: train/raw_data/0/3447.jpg
#   inflating: train/raw_data/0/3448.jpg
#   inflating: train/raw_data/0/3449.jpg
#   inflating: train/raw_data/0/344.jpg
#   inflating: train/raw_data/0/3450.jpg
#   inflating: train/raw_data/0/3451.jpg
#   inflating: train/raw_data/0/3452.jpg
#   inflating: train/raw_data/0/3453.jpg
#   inflating: train/raw_data/0/3454.jpg
#   inflating: train/raw_data/0/3455.jpg
#   inflating: train/raw_data/0/3456.jpg
#   inflating: train/raw_data/0/3457.jpg
#   inflating: train/raw_data/0/3458.jpg
#   inflating: train/raw_data/0/3459.jpg
#   inflating: train/raw_data/0/345.jpg
#   inflating: train/raw_data/0/3460.jpg
#   inflating: train/raw_data/0/3461.jpg
#   inflating: train/raw_data/0/3462.jpg
#   inflating: train/raw_data/0/3463.jpg
#   inflating: train/raw_data/0/3464.jpg
#   inflating: train/raw_data/0/3465.jpg
#   inflating: train/raw_data/0/3466.jpg
#   inflating: train/raw_data/0/3467.jpg
#   inflating: train/raw_data/0/3468.jpg
#   inflating: train/raw_data/0/3469.jpg
#   inflating: train/raw_data/0/346.jpg
#   inflating: train/raw_data/0/3470.jpg
#   inflating: train/raw_data/0/3471.jpg
#   inflating: train/raw_data/0/3472.jpg
#   inflating: train/raw_data/0/3473.jpg
#   inflating: train/raw_data/0/3474.jpg
#   inflating: train/raw_data/0/3475.jpg
#   inflating: train/raw_data/0/3476.jpg
#   inflating: train/raw_data/0/3477.jpg
#   inflating: train/raw_data/0/3478.jpg
#   inflating: train/raw_data/0/3479.jpg
#   inflating: train/raw_data/0/347.jpg
#   inflating: train/raw_data/0/3480.jpg
#   inflating: train/raw_data/0/3481.jpg
#   inflating: train/raw_data/0/3482.jpg
#   inflating: train/raw_data/0/3483.jpg
#   inflating: train/raw_data/0/3484.jpg
#   inflating: train/raw_data/0/3485.jpg
#   inflating: train/raw_data/0/3486.jpg
#   inflating: train/raw_data/0/3487.jpg
#   inflating: train/raw_data/0/3488.jpg
#   inflating: train/raw_data/0/3489.jpg
#   inflating: train/raw_data/0/348.jpg
#   inflating: train/raw_data/0/3490.jpg
#   inflating: train/raw_data/0/3491.jpg
#   inflating: train/raw_data/0/3492.jpg
#   inflating: train/raw_data/0/3493.jpg
#   inflating: train/raw_data/0/3494.jpg
#   inflating: train/raw_data/0/3495.jpg
#   inflating: train/raw_data/0/3496.jpg
#   inflating: train/raw_data/0/3497.jpg
#   inflating: train/raw_data/0/3498.jpg
#   inflating: train/raw_data/0/3499.jpg
#   inflating: train/raw_data/0/349.jpg
#   inflating: train/raw_data/0/34.jpg
#   inflating: train/raw_data/0/3500.jpg
#   inflating: train/raw_data/0/3501.jpg
#   inflating: train/raw_data/0/3502.jpg
#   inflating: train/raw_data/0/3503.jpg
#   inflating: train/raw_data/0/3504.jpg
#   inflating: train/raw_data/0/3505.jpg
#   inflating: train/raw_data/0/3506.jpg
#   inflating: train/raw_data/0/3507.jpg
#   inflating: train/raw_data/0/3508.jpg
#   inflating: train/raw_data/0/3509.jpg
#   inflating: train/raw_data/0/350.jpg
#   inflating: train/raw_data/0/3510.jpg
#   inflating: train/raw_data/0/3511.jpg
#   inflating: train/raw_data/0/3512.jpg
#   inflating: train/raw_data/0/3513.jpg
#   inflating: train/raw_data/0/3514.jpg
#   inflating: train/raw_data/0/3515.jpg
#   inflating: train/raw_data/0/3516.jpg
#   inflating: train/raw_data/0/3517.jpg
#   inflating: train/raw_data/0/3518.jpg
#   inflating: train/raw_data/0/3519.jpg
#   inflating: train/raw_data/0/351.jpg
#   inflating: train/raw_data/0/3520.jpg
#   inflating: train/raw_data/0/3521.jpg
#   inflating: train/raw_data/0/3522.jpg
#   inflating: train/raw_data/0/3523.jpg
#   inflating: train/raw_data/0/3524.jpg
#   inflating: train/raw_data/0/3525.jpg
#   inflating: train/raw_data/0/3526.jpg
#   inflating: train/raw_data/0/3527.jpg
#   inflating: train/raw_data/0/3528.jpg
#   inflating: train/raw_data/0/3529.jpg
#   inflating: train/raw_data/0/352.jpg
#   inflating: train/raw_data/0/3530.jpg
#   inflating: train/raw_data/0/3531.jpg
#   inflating: train/raw_data/0/3532.jpg
#   inflating: train/raw_data/0/3533.jpg
#   inflating: train/raw_data/0/3534.jpg
#   inflating: train/raw_data/0/3535.jpg
#   inflating: train/raw_data/0/3536.jpg
#   inflating: train/raw_data/0/3537.jpg
#   inflating: train/raw_data/0/3538.jpg
#   inflating: train/raw_data/0/3539.jpg
#   inflating: train/raw_data/0/353.jpg
#   inflating: train/raw_data/0/3540.jpg
#   inflating: train/raw_data/0/3541.jpg
#   inflating: train/raw_data/0/3542.jpg
#   inflating: train/raw_data/0/3543.jpg
#   inflating: train/raw_data/0/3544.jpg
#   inflating: train/raw_data/0/3545.jpg
#   inflating: train/raw_data/0/3546.jpg
#   inflating: train/raw_data/0/3547.jpg
#   inflating: train/raw_data/0/3548.jpg
#   inflating: train/raw_data/0/3549.jpg
#   inflating: train/raw_data/0/354.jpg
#   inflating: train/raw_data/0/3550.jpg
#   inflating: train/raw_data/0/3551.jpg
#   inflating: train/raw_data/0/3552.jpg
#   inflating: train/raw_data/0/3553.jpg
#   inflating: train/raw_data/0/3554.jpg
#   inflating: train/raw_data/0/3555.jpg
#   inflating: train/raw_data/0/3556.jpg
#   inflating: train/raw_data/0/3557.jpg
#   inflating: train/raw_data/0/3558.jpg
#   inflating: train/raw_data/0/3559.jpg
#   inflating: train/raw_data/0/355.jpg
#   inflating: train/raw_data/0/3560.jpg
#   inflating: train/raw_data/0/3561.jpg
#   inflating: train/raw_data/0/3562.jpg
#   inflating: train/raw_data/0/3563.jpg
#   inflating: train/raw_data/0/3564.jpg
#   inflating: train/raw_data/0/3565.jpg
#   inflating: train/raw_data/0/3566.jpg
#   inflating: train/raw_data/0/3567.jpg
#   inflating: train/raw_data/0/3568.jpg
#   inflating: train/raw_data/0/3569.jpg
#   inflating: train/raw_data/0/356.jpg
#   inflating: train/raw_data/0/3570.jpg
#   inflating: train/raw_data/0/3571.jpg
#   inflating: train/raw_data/0/3572.jpg
#   inflating: train/raw_data/0/3573.jpg
#   inflating: train/raw_data/0/3574.jpg
#   inflating: train/raw_data/0/3575.jpg
#   inflating: train/raw_data/0/3576.jpg
#   inflating: train/raw_data/0/3577.jpg
#   inflating: train/raw_data/0/3578.jpg
#   inflating: train/raw_data/0/3579.jpg
#   inflating: train/raw_data/0/357.jpg
#   inflating: train/raw_data/0/3580.jpg
#   inflating: train/raw_data/0/3581.jpg
#   inflating: train/raw_data/0/3582.jpg
#   inflating: train/raw_data/0/3583.jpg
#   inflating: train/raw_data/0/3584.jpg
#   inflating: train/raw_data/0/3585.jpg
#   inflating: train/raw_data/0/3586.jpg
#   inflating: train/raw_data/0/3587.jpg
#   inflating: train/raw_data/0/3588.jpg
#   inflating: train/raw_data/0/3589.jpg
#   inflating: train/raw_data/0/358.jpg
#   inflating: train/raw_data/0/3590.jpg
#   inflating: train/raw_data/0/3591.jpg
#   inflating: train/raw_data/0/3592.jpg
#   inflating: train/raw_data/0/3593.jpg
#   inflating: train/raw_data/0/3594.jpg
#   inflating: train/raw_data/0/3595.jpg
#   inflating: train/raw_data/0/3596.jpg
#   inflating: train/raw_data/0/3597.jpg
#   inflating: train/raw_data/0/3598.jpg
#   inflating: train/raw_data/0/3599.jpg
#   inflating: train/raw_data/0/359.jpg
#   inflating: train/raw_data/0/35.jpg
#   inflating: train/raw_data/0/3600.jpg
#   inflating: train/raw_data/0/3601.jpg
#   inflating: train/raw_data/0/3602.jpg
#   inflating: train/raw_data/0/3603.jpg
#   inflating: train/raw_data/0/3604.jpg
#   inflating: train/raw_data/0/3605.jpg
#   inflating: train/raw_data/0/3606.jpg
#   inflating: train/raw_data/0/3607.jpg
#   inflating: train/raw_data/0/3608.jpg
#   inflating: train/raw_data/0/3609.jpg
#   inflating: train/raw_data/0/360.jpg
#   inflating: train/raw_data/0/3610.jpg
#   inflating: train/raw_data/0/3611.jpg
#   inflating: train/raw_data/0/3612.jpg
#   inflating: train/raw_data/0/3613.jpg
#   inflating: train/raw_data/0/3614.jpg
#   inflating: train/raw_data/0/3615.jpg
#   inflating: train/raw_data/0/3616.jpg
#   inflating: train/raw_data/0/3617.jpg
#   inflating: train/raw_data/0/3618.jpg
#   inflating: train/raw_data/0/3619.jpg
#   inflating: train/raw_data/0/361.jpg
#   inflating: train/raw_data/0/3620.jpg
#   inflating: train/raw_data/0/3621.jpg
#   inflating: train/raw_data/0/3622.jpg
#   inflating: train/raw_data/0/3623.jpg
#   inflating: train/raw_data/0/3624.jpg
#   inflating: train/raw_data/0/3625.jpg
#   inflating: train/raw_data/0/3626.jpg
#   inflating: train/raw_data/0/3627.jpg
#   inflating: train/raw_data/0/3628.jpg
#   inflating: train/raw_data/0/3629.jpg
#   inflating: train/raw_data/0/362.jpg
#   inflating: train/raw_data/0/3630.jpg
#   inflating: train/raw_data/0/3631.jpg
#   inflating: train/raw_data/0/3632.jpg
#   inflating: train/raw_data/0/3633.jpg
#   inflating: train/raw_data/0/3634.jpg
#   inflating: train/raw_data/0/3635.jpg
#   inflating: train/raw_data/0/3636.jpg
#   inflating: train/raw_data/0/3637.jpg
#   inflating: train/raw_data/0/3638.jpg
#   inflating: train/raw_data/0/3639.jpg
#   inflating: train/raw_data/0/363.jpg
#   inflating: train/raw_data/0/3640.jpg
#   inflating: train/raw_data/0/3641.jpg
#   inflating: train/raw_data/0/3642.jpg
#   inflating: train/raw_data/0/3643.jpg
#   inflating: train/raw_data/0/3644.jpg
#   inflating: train/raw_data/0/3645.jpg
#   inflating: train/raw_data/0/3646.jpg
#   inflating: train/raw_data/0/3647.jpg
#   inflating: train/raw_data/0/3648.jpg
#   inflating: train/raw_data/0/3649.jpg
#   inflating: train/raw_data/0/364.jpg
#   inflating: train/raw_data/0/3650.jpg
#   inflating: train/raw_data/0/3651.jpg
#   inflating: train/raw_data/0/3652.jpg
#   inflating: train/raw_data/0/3653.jpg
#   inflating: train/raw_data/0/3654.jpg
#   inflating: train/raw_data/0/3655.jpg
#   inflating: train/raw_data/0/3656.jpg
#   inflating: train/raw_data/0/3657.jpg
#   inflating: train/raw_data/0/3658.jpg
#   inflating: train/raw_data/0/3659.jpg
#   inflating: train/raw_data/0/365.jpg
#   inflating: train/raw_data/0/3660.jpg
#   inflating: train/raw_data/0/3661.jpg
#   inflating: train/raw_data/0/3662.jpg
#   inflating: train/raw_data/0/3663.jpg
#   inflating: train/raw_data/0/3664.jpg
#   inflating: train/raw_data/0/3665.jpg
#   inflating: train/raw_data/0/3666.jpg
#   inflating: train/raw_data/0/3667.jpg
#   inflating: train/raw_data/0/3668.jpg
#   inflating: train/raw_data/0/3669.jpg
#   inflating: train/raw_data/0/366.jpg
#   inflating: train/raw_data/0/3670.jpg
#   inflating: train/raw_data/0/3671.jpg
#   inflating: train/raw_data/0/3672.jpg
#   inflating: train/raw_data/0/3673.jpg
#   inflating: train/raw_data/0/3674.jpg
#   inflating: train/raw_data/0/3675.jpg
#   inflating: train/raw_data/0/3676.jpg
#   inflating: train/raw_data/0/3677.jpg
#   inflating: train/raw_data/0/3678.jpg
#   inflating: train/raw_data/0/3679.jpg
#   inflating: train/raw_data/0/367.jpg
#   inflating: train/raw_data/0/3680.jpg
#   inflating: train/raw_data/0/3681.jpg
#   inflating: train/raw_data/0/3682.jpg
#   inflating: train/raw_data/0/3683.jpg
#   inflating: train/raw_data/0/3684.jpg
#   inflating: train/raw_data/0/3685.jpg
#   inflating: train/raw_data/0/3686.jpg
#   inflating: train/raw_data/0/3687.jpg
#   inflating: train/raw_data/0/3688.jpg
#   inflating: train/raw_data/0/3689.jpg
#   inflating: train/raw_data/0/368.jpg
#   inflating: train/raw_data/0/3690.jpg
#   inflating: train/raw_data/0/3691.jpg
#   inflating: train/raw_data/0/3692.jpg
#   inflating: train/raw_data/0/3693.jpg
#   inflating: train/raw_data/0/3694.jpg
#   inflating: train/raw_data/0/3695.jpg
#   inflating: train/raw_data/0/3696.jpg
#   inflating: train/raw_data/0/3697.jpg
#   inflating: train/raw_data/0/3698.jpg
#   inflating: train/raw_data/0/3699.jpg
#   inflating: train/raw_data/0/369.jpg
#   inflating: train/raw_data/0/36.jpg
#   inflating: train/raw_data/0/3700.jpg
#   inflating: train/raw_data/0/3701.jpg
#   inflating: train/raw_data/0/3702.jpg
#   inflating: train/raw_data/0/3703.jpg
#   inflating: train/raw_data/0/370.jpg
#   inflating: train/raw_data/0/371.jpg
#   inflating: train/raw_data/0/372.jpg
#   inflating: train/raw_data/0/373.jpg
#   inflating: train/raw_data/0/374.jpg
#   inflating: train/raw_data/0/375.jpg
#   inflating: train/raw_data/0/376.jpg
#   inflating: train/raw_data/0/377.jpg
#   inflating: train/raw_data/0/378.jpg
#   inflating: train/raw_data/0/379.jpg
#   inflating: train/raw_data/0/37.jpg
#   inflating: train/raw_data/0/380.jpg
#   inflating: train/raw_data/0/381.jpg
#   inflating: train/raw_data/0/382.jpg
#   inflating: train/raw_data/0/383.jpg
#   inflating: train/raw_data/0/384.jpg
#   inflating: train/raw_data/0/385.jpg
#   inflating: train/raw_data/0/386.jpg
#   inflating: train/raw_data/0/387.jpg
#   inflating: train/raw_data/0/388.jpg
#   inflating: train/raw_data/0/389.jpg
#   inflating: train/raw_data/0/38.jpg
#   inflating: train/raw_data/0/390.jpg
#   inflating: train/raw_data/0/391.jpg
#   inflating: train/raw_data/0/392.jpg
#   inflating: train/raw_data/0/393.jpg
#   inflating: train/raw_data/0/394.jpg
#   inflating: train/raw_data/0/395.jpg
#   inflating: train/raw_data/0/396.jpg
#   inflating: train/raw_data/0/397.jpg
#   inflating: train/raw_data/0/398.jpg
#   inflating: train/raw_data/0/399.jpg
#   inflating: train/raw_data/0/39.jpg
#   inflating: train/raw_data/0/3.jpg
#   inflating: train/raw_data/0/400.jpg
#   inflating: train/raw_data/0/401.jpg
#   inflating: train/raw_data/0/402.jpg
#   inflating: train/raw_data/0/403.jpg
#   inflating: train/raw_data/0/404.jpg
#   inflating: train/raw_data/0/405.jpg
#   inflating: train/raw_data/0/406.jpg
#   inflating: train/raw_data/0/407.jpg
#   inflating: train/raw_data/0/408.jpg
#   inflating: train/raw_data/0/409.jpg
#   inflating: train/raw_data/0/40.jpg
#   inflating: train/raw_data/0/410.jpg
#   inflating: train/raw_data/0/411.jpg
#   inflating: train/raw_data/0/412.jpg
#   inflating: train/raw_data/0/413.jpg
#   inflating: train/raw_data/0/414.jpg
#   inflating: train/raw_data/0/415.jpg
#   inflating: train/raw_data/0/416.jpg
#   inflating: train/raw_data/0/417.jpg
#   inflating: train/raw_data/0/418.jpg
#   inflating: train/raw_data/0/419.jpg
#   inflating: train/raw_data/0/41.jpg
#   inflating: train/raw_data/0/420.jpg
#   inflating: train/raw_data/0/421.jpg
#   inflating: train/raw_data/0/422.jpg
#   inflating: train/raw_data/0/423.jpg
#   inflating: train/raw_data/0/424.jpg
#   inflating: train/raw_data/0/425.jpg
#   inflating: train/raw_data/0/426.jpg
#   inflating: train/raw_data/0/427.jpg
#   inflating: train/raw_data/0/428.jpg
#   inflating: train/raw_data/0/429.jpg
#   inflating: train/raw_data/0/42.jpg
#   inflating: train/raw_data/0/430.jpg
#   inflating: train/raw_data/0/431.jpg
#   inflating: train/raw_data/0/432.jpg
#   inflating: train/raw_data/0/433.jpg
#   inflating: train/raw_data/0/434.jpg
#   inflating: train/raw_data/0/435.jpg
#   inflating: train/raw_data/0/436.jpg
#   inflating: train/raw_data/0/437.jpg
#   inflating: train/raw_data/0/438.jpg
#   inflating: train/raw_data/0/439.jpg
#   inflating: train/raw_data/0/43.jpg
#   inflating: train/raw_data/0/440.jpg
#   inflating: train/raw_data/0/441.jpg
#   inflating: train/raw_data/0/442.jpg
#   inflating: train/raw_data/0/443.jpg
#   inflating: train/raw_data/0/444.jpg
#   inflating: train/raw_data/0/445.jpg
#   inflating: train/raw_data/0/446.jpg
#   inflating: train/raw_data/0/447.jpg
#   inflating: train/raw_data/0/448.jpg
#   inflating: train/raw_data/0/449.jpg
#   inflating: train/raw_data/0/44.jpg
#   inflating: train/raw_data/0/450.jpg
#   inflating: train/raw_data/0/451.jpg
#   inflating: train/raw_data/0/452.jpg
#   inflating: train/raw_data/0/453.jpg
#   inflating: train/raw_data/0/454.jpg
#   inflating: train/raw_data/0/455.jpg
#   inflating: train/raw_data/0/456.jpg
#   inflating: train/raw_data/0/457.jpg
#   inflating: train/raw_data/0/458.jpg
#   inflating: train/raw_data/0/459.jpg
#   inflating: train/raw_data/0/45.jpg
#   inflating: train/raw_data/0/460.jpg
#   inflating: train/raw_data/0/461.jpg
#   inflating: train/raw_data/0/462.jpg
#   inflating: train/raw_data/0/463.jpg
#   inflating: train/raw_data/0/464.jpg
#   inflating: train/raw_data/0/465.jpg
#   inflating: train/raw_data/0/466.jpg
#   inflating: train/raw_data/0/467.jpg
#   inflating: train/raw_data/0/468.jpg
#   inflating: train/raw_data/0/469.jpg
#   inflating: train/raw_data/0/46.jpg
#   inflating: train/raw_data/0/470.jpg
#   inflating: train/raw_data/0/471.jpg
#   inflating: train/raw_data/0/472.jpg
#   inflating: train/raw_data/0/473.jpg
#   inflating: train/raw_data/0/474.jpg
#   inflating: train/raw_data/0/475.jpg
#   inflating: train/raw_data/0/476.jpg
#   inflating: train/raw_data/0/477.jpg
#   inflating: train/raw_data/0/478.jpg
#   inflating: train/raw_data/0/479.jpg
#   inflating: train/raw_data/0/47.jpg
#   inflating: train/raw_data/0/480.jpg
#   inflating: train/raw_data/0/481.jpg
#   inflating: train/raw_data/0/482.jpg
#   inflating: train/raw_data/0/483.jpg
#   inflating: train/raw_data/0/484.jpg
#   inflating: train/raw_data/0/485.jpg
#   inflating: train/raw_data/0/486.jpg
#   inflating: train/raw_data/0/487.jpg
#   inflating: train/raw_data/0/488.jpg
#   inflating: train/raw_data/0/489.jpg
#   inflating: train/raw_data/0/48.jpg
#   inflating: train/raw_data/0/490.jpg
#   inflating: train/raw_data/0/491.jpg
#   inflating: train/raw_data/0/492.jpg
#   inflating: train/raw_data/0/493.jpg
#   inflating: train/raw_data/0/494.jpg
#   inflating: train/raw_data/0/495.jpg
#   inflating: train/raw_data/0/496.jpg
#   inflating: train/raw_data/0/497.jpg
#   inflating: train/raw_data/0/498.jpg
#   inflating: train/raw_data/0/499.jpg
#   inflating: train/raw_data/0/49.jpg
#   inflating: train/raw_data/0/4.jpg
#   inflating: train/raw_data/0/500.jpg
#   inflating: train/raw_data/0/501.jpg
#   inflating: train/raw_data/0/502.jpg
#   inflating: train/raw_data/0/503.jpg
#   inflating: train/raw_data/0/504.jpg
#   inflating: train/raw_data/0/505.jpg
#   inflating: train/raw_data/0/506.jpg
#   inflating: train/raw_data/0/507.jpg
#   inflating: train/raw_data/0/508.jpg
#   inflating: train/raw_data/0/509.jpg
#   inflating: train/raw_data/0/50.jpg
#   inflating: train/raw_data/0/510.jpg
#   inflating: train/raw_data/0/511.jpg
#   inflating: train/raw_data/0/512.jpg
#   inflating: train/raw_data/0/513.jpg
#   inflating: train/raw_data/0/514.jpg
#   inflating: train/raw_data/0/515.jpg
#   inflating: train/raw_data/0/516.jpg
#   inflating: train/raw_data/0/517.jpg
#   inflating: train/raw_data/0/518.jpg
#   inflating: train/raw_data/0/519.jpg
#   inflating: train/raw_data/0/51.jpg
#   inflating: train/raw_data/0/520.jpg
#   inflating: train/raw_data/0/521.jpg
#   inflating: train/raw_data/0/522.jpg
#   inflating: train/raw_data/0/523.jpg
#   inflating: train/raw_data/0/524.jpg
#   inflating: train/raw_data/0/525.jpg
#   inflating: train/raw_data/0/526.jpg
#   inflating: train/raw_data/0/527.jpg
#   inflating: train/raw_data/0/528.jpg
#   inflating: train/raw_data/0/529.jpg
#   inflating: train/raw_data/0/52.jpg
#   inflating: train/raw_data/0/530.jpg
#   inflating: train/raw_data/0/531.jpg
#   inflating: train/raw_data/0/532.jpg
#   inflating: train/raw_data/0/533.jpg
#   inflating: train/raw_data/0/534.jpg
#   inflating: train/raw_data/0/535.jpg
#   inflating: train/raw_data/0/536.jpg
#   inflating: train/raw_data/0/537.jpg
#   inflating: train/raw_data/0/538.jpg
#   inflating: train/raw_data/0/539.jpg
#   inflating: train/raw_data/0/53.jpg
#   inflating: train/raw_data/0/540.jpg
#   inflating: train/raw_data/0/541.jpg
#   inflating: train/raw_data/0/542.jpg
#   inflating: train/raw_data/0/543.jpg
#   inflating: train/raw_data/0/544.jpg
#   inflating: train/raw_data/0/545.jpg
#   inflating: train/raw_data/0/546.jpg
#   inflating: train/raw_data/0/547.jpg
#   inflating: train/raw_data/0/548.jpg
#   inflating: train/raw_data/0/549.jpg
#   inflating: train/raw_data/0/54.jpg
#   inflating: train/raw_data/0/550.jpg
#   inflating: train/raw_data/0/551.jpg
#   inflating: train/raw_data/0/552.jpg
#   inflating: train/raw_data/0/553.jpg
#   inflating: train/raw_data/0/554.jpg
#   inflating: train/raw_data/0/555.jpg
#   inflating: train/raw_data/0/556.jpg
#   inflating: train/raw_data/0/557.jpg
#   inflating: train/raw_data/0/558.jpg
#   inflating: train/raw_data/0/559.jpg
#   inflating: train/raw_data/0/55.jpg
#   inflating: train/raw_data/0/560.jpg
#   inflating: train/raw_data/0/561.jpg
#   inflating: train/raw_data/0/562.jpg
#   inflating: train/raw_data/0/563.jpg
#   inflating: train/raw_data/0/564.jpg
#   inflating: train/raw_data/0/565.jpg
#   inflating: train/raw_data/0/566.jpg
#   inflating: train/raw_data/0/567.jpg
#   inflating: train/raw_data/0/568.jpg
#   inflating: train/raw_data/0/569.jpg
#   inflating: train/raw_data/0/56.jpg
#   inflating: train/raw_data/0/570.jpg
#   inflating: train/raw_data/0/571.jpg
#   inflating: train/raw_data/0/572.jpg
#   inflating: train/raw_data/0/573.jpg
#   inflating: train/raw_data/0/574.jpg
#   inflating: train/raw_data/0/575.jpg
#   inflating: train/raw_data/0/576.jpg
#   inflating: train/raw_data/0/577.jpg
#   inflating: train/raw_data/0/578.jpg
#   inflating: train/raw_data/0/579.jpg
#   inflating: train/raw_data/0/57.jpg
#   inflating: train/raw_data/0/580.jpg
#   inflating: train/raw_data/0/581.jpg
#   inflating: train/raw_data/0/582.jpg
#   inflating: train/raw_data/0/583.jpg
#   inflating: train/raw_data/0/584.jpg
#   inflating: train/raw_data/0/585.jpg
#   inflating: train/raw_data/0/586.jpg
#   inflating: train/raw_data/0/587.jpg
#   inflating: train/raw_data/0/588.jpg
#   inflating: train/raw_data/0/589.jpg
#   inflating: train/raw_data/0/58.jpg
#   inflating: train/raw_data/0/590.jpg
#   inflating: train/raw_data/0/591.jpg
#   inflating: train/raw_data/0/592.jpg
#   inflating: train/raw_data/0/593.jpg
#   inflating: train/raw_data/0/594.jpg
#   inflating: train/raw_data/0/595.jpg
#   inflating: train/raw_data/0/596.jpg
#   inflating: train/raw_data/0/597.jpg
#   inflating: train/raw_data/0/598.jpg
#   inflating: train/raw_data/0/599.jpg
#   inflating: train/raw_data/0/59.jpg
#   inflating: train/raw_data/0/5.jpg
#   inflating: train/raw_data/0/600.jpg
#   inflating: train/raw_data/0/601.jpg
#   inflating: train/raw_data/0/602.jpg
#   inflating: train/raw_data/0/603.jpg
#   inflating: train/raw_data/0/604.jpg
#   inflating: train/raw_data/0/605.jpg
#   inflating: train/raw_data/0/606.jpg
#   inflating: train/raw_data/0/607.jpg
#   inflating: train/raw_data/0/608.jpg
#   inflating: train/raw_data/0/609.jpg
#   inflating: train/raw_data/0/60.jpg
#   inflating: train/raw_data/0/610.jpg
#   inflating: train/raw_data/0/611.jpg
#   inflating: train/raw_data/0/612.jpg
#   inflating: train/raw_data/0/613.jpg
#   inflating: train/raw_data/0/614.jpg
#   inflating: train/raw_data/0/615.jpg
#   inflating: train/raw_data/0/616.jpg
#   inflating: train/raw_data/0/617.jpg
#   inflating: train/raw_data/0/618.jpg
#   inflating: train/raw_data/0/619.jpg
#   inflating: train/raw_data/0/61.jpg
#   inflating: train/raw_data/0/620.jpg
#   inflating: train/raw_data/0/621.jpg
#   inflating: train/raw_data/0/622.jpg
#   inflating: train/raw_data/0/623.jpg
#   inflating: train/raw_data/0/624.jpg
#   inflating: train/raw_data/0/625.jpg
#   inflating: train/raw_data/0/626.jpg
#   inflating: train/raw_data/0/627.jpg
#   inflating: train/raw_data/0/628.jpg
#   inflating: train/raw_data/0/629.jpg
#   inflating: train/raw_data/0/62.jpg
#   inflating: train/raw_data/0/630.jpg
#   inflating: train/raw_data/0/631.jpg
#   inflating: train/raw_data/0/632.jpg
#   inflating: train/raw_data/0/633.jpg
#   inflating: train/raw_data/0/634.jpg
#   inflating: train/raw_data/0/635.jpg
#   inflating: train/raw_data/0/636.jpg
#   inflating: train/raw_data/0/637.jpg
#   inflating: train/raw_data/0/638.jpg
#   inflating: train/raw_data/0/639.jpg
#   inflating: train/raw_data/0/63.jpg
#   inflating: train/raw_data/0/640.jpg
#   inflating: train/raw_data/0/641.jpg
#   inflating: train/raw_data/0/642.jpg
#   inflating: train/raw_data/0/643.jpg
#   inflating: train/raw_data/0/644.jpg
#   inflating: train/raw_data/0/645.jpg
#   inflating: train/raw_data/0/646.jpg
#   inflating: train/raw_data/0/647.jpg
#   inflating: train/raw_data/0/648.jpg
#   inflating: train/raw_data/0/649.jpg
#   inflating: train/raw_data/0/64.jpg
#   inflating: train/raw_data/0/650.jpg
#   inflating: train/raw_data/0/651.jpg
#   inflating: train/raw_data/0/652.jpg
#   inflating: train/raw_data/0/653.jpg
#   inflating: train/raw_data/0/654.jpg
#   inflating: train/raw_data/0/655.jpg
#   inflating: train/raw_data/0/656.jpg
#   inflating: train/raw_data/0/657.jpg
#   inflating: train/raw_data/0/658.jpg
#   inflating: train/raw_data/0/659.jpg
#   inflating: train/raw_data/0/65.jpg
#   inflating: train/raw_data/0/660.jpg
#   inflating: train/raw_data/0/661.jpg
#   inflating: train/raw_data/0/662.jpg
#   inflating: train/raw_data/0/663.jpg
#   inflating: train/raw_data/0/664.jpg
#   inflating: train/raw_data/0/665.jpg
#   inflating: train/raw_data/0/666.jpg
#   inflating: train/raw_data/0/667.jpg
#   inflating: train/raw_data/0/668.jpg
#   inflating: train/raw_data/0/669.jpg
#   inflating: train/raw_data/0/66.jpg
#   inflating: train/raw_data/0/670.jpg
#   inflating: train/raw_data/0/671.jpg
#   inflating: train/raw_data/0/672.jpg
#   inflating: train/raw_data/0/673.jpg
#   inflating: train/raw_data/0/674.jpg
#   inflating: train/raw_data/0/675.jpg
#   inflating: train/raw_data/0/676.jpg
#   inflating: train/raw_data/0/677.jpg
#   inflating: train/raw_data/0/678.jpg
#   inflating: train/raw_data/0/679.jpg
#   inflating: train/raw_data/0/67.jpg
#   inflating: train/raw_data/0/680.jpg
#   inflating: train/raw_data/0/681.jpg
#   inflating: train/raw_data/0/682.jpg
#   inflating: train/raw_data/0/683.jpg
#   inflating: train/raw_data/0/684.jpg
#   inflating: train/raw_data/0/685.jpg
#   inflating: train/raw_data/0/686.jpg
#   inflating: train/raw_data/0/687.jpg
#   inflating: train/raw_data/0/688.jpg
#   inflating: train/raw_data/0/689.jpg
#   inflating: train/raw_data/0/68.jpg
#   inflating: train/raw_data/0/690.jpg
#   inflating: train/raw_data/0/691.jpg
#   inflating: train/raw_data/0/692.jpg
#   inflating: train/raw_data/0/693.jpg
#   inflating: train/raw_data/0/694.jpg
#   inflating: train/raw_data/0/695.jpg
#   inflating: train/raw_data/0/696.jpg
#   inflating: train/raw_data/0/697.jpg
#   inflating: train/raw_data/0/698.jpg
#   inflating: train/raw_data/0/699.jpg
#   inflating: train/raw_data/0/69.jpg
#   inflating: train/raw_data/0/6.jpg
#   inflating: train/raw_data/0/700.jpg
#   inflating: train/raw_data/0/701.jpg
#   inflating: train/raw_data/0/702.jpg
#   inflating: train/raw_data/0/703.jpg
#   inflating: train/raw_data/0/704.jpg
#   inflating: train/raw_data/0/705.jpg
#   inflating: train/raw_data/0/706.jpg
#   inflating: train/raw_data/0/707.jpg
#   inflating: train/raw_data/0/708.jpg
#   inflating: train/raw_data/0/709.jpg
#   inflating: train/raw_data/0/70.jpg
#   inflating: train/raw_data/0/710.jpg
#   inflating: train/raw_data/0/711.jpg
#   inflating: train/raw_data/0/712.jpg
#   inflating: train/raw_data/0/713.jpg
#   inflating: train/raw_data/0/714.jpg
#   inflating: train/raw_data/0/715.jpg
#   inflating: train/raw_data/0/716.jpg
#   inflating: train/raw_data/0/717.jpg
#   inflating: train/raw_data/0/718.jpg
#   inflating: train/raw_data/0/719.jpg
#   inflating: train/raw_data/0/71.jpg
#   inflating: train/raw_data/0/720.jpg
#   inflating: train/raw_data/0/721.jpg
#   inflating: train/raw_data/0/722.jpg
#   inflating: train/raw_data/0/723.jpg
#   inflating: train/raw_data/0/724.jpg
#   inflating: train/raw_data/0/725.jpg
#   inflating: train/raw_data/0/726.jpg
#   inflating: train/raw_data/0/727.jpg
#   inflating: train/raw_data/0/728.jpg
#   inflating: train/raw_data/0/729.jpg
#   inflating: train/raw_data/0/72.jpg
#   inflating: train/raw_data/0/730.jpg
#   inflating: train/raw_data/0/731.jpg
#   inflating: train/raw_data/0/732.jpg
#   inflating: train/raw_data/0/733.jpg
#   inflating: train/raw_data/0/734.jpg
#   inflating: train/raw_data/0/735.jpg
#   inflating: train/raw_data/0/736.jpg
#   inflating: train/raw_data/0/737.jpg
#   inflating: train/raw_data/0/738.jpg
#   inflating: train/raw_data/0/739.jpg
#   inflating: train/raw_data/0/73.jpg
#   inflating: train/raw_data/0/740.jpg
#   inflating: train/raw_data/0/741.jpg
#   inflating: train/raw_data/0/742.jpg
#   inflating: train/raw_data/0/743.jpg
#   inflating: train/raw_data/0/744.jpg
#   inflating: train/raw_data/0/745.jpg
#   inflating: train/raw_data/0/746.jpg
#   inflating: train/raw_data/0/747.jpg
#   inflating: train/raw_data/0/748.jpg
#   inflating: train/raw_data/0/749.jpg
#   inflating: train/raw_data/0/74.jpg
#   inflating: train/raw_data/0/750.jpg
#   inflating: train/raw_data/0/751.jpg
#   inflating: train/raw_data/0/752.jpg
#   inflating: train/raw_data/0/753.jpg
#   inflating: train/raw_data/0/754.jpg
#   inflating: train/raw_data/0/755.jpg
#   inflating: train/raw_data/0/756.jpg
#   inflating: train/raw_data/0/757.jpg
#   inflating: train/raw_data/0/758.jpg
#   inflating: train/raw_data/0/759.jpg
#   inflating: train/raw_data/0/75.jpg
#   inflating: train/raw_data/0/760.jpg
#   inflating: train/raw_data/0/761.jpg
#   inflating: train/raw_data/0/762.jpg
#   inflating: train/raw_data/0/763.jpg
#   inflating: train/raw_data/0/764.jpg
#   inflating: train/raw_data/0/765.jpg
#   inflating: train/raw_data/0/766.jpg
#   inflating: train/raw_data/0/767.jpg
#   inflating: train/raw_data/0/768.jpg
#   inflating: train/raw_data/0/769.jpg
#   inflating: train/raw_data/0/76.jpg
#   inflating: train/raw_data/0/770.jpg
#   inflating: train/raw_data/0/771.jpg
#   inflating: train/raw_data/0/772.jpg
#   inflating: train/raw_data/0/773.jpg
#   inflating: train/raw_data/0/774.jpg
#   inflating: train/raw_data/0/775.jpg
#   inflating: train/raw_data/0/776.jpg
#   inflating: train/raw_data/0/777.jpg
#   inflating: train/raw_data/0/778.jpg
#   inflating: train/raw_data/0/779.jpg
#   inflating: train/raw_data/0/77.jpg
#   inflating: train/raw_data/0/780.jpg
#   inflating: train/raw_data/0/781.jpg
#   inflating: train/raw_data/0/782.jpg
#   inflating: train/raw_data/0/783.jpg
#   inflating: train/raw_data/0/784.jpg
#   inflating: train/raw_data/0/785.jpg
#   inflating: train/raw_data/0/786.jpg
#   inflating: train/raw_data/0/787.jpg
#   inflating: train/raw_data/0/788.jpg
#   inflating: train/raw_data/0/789.jpg
#   inflating: train/raw_data/0/78.jpg
#   inflating: train/raw_data/0/790.jpg
#   inflating: train/raw_data/0/791.jpg
#   inflating: train/raw_data/0/792.jpg
#   inflating: train/raw_data/0/793.jpg
#   inflating: train/raw_data/0/794.jpg
#   inflating: train/raw_data/0/795.jpg
#   inflating: train/raw_data/0/796.jpg
#   inflating: train/raw_data/0/797.jpg
#   inflating: train/raw_data/0/798.jpg
#   inflating: train/raw_data/0/799.jpg
#   inflating: train/raw_data/0/79.jpg
#   inflating: train/raw_data/0/7.jpg
#   inflating: train/raw_data/0/800.jpg
#   inflating: train/raw_data/0/801.jpg
#   inflating: train/raw_data/0/802.jpg
#   inflating: train/raw_data/0/803.jpg
#   inflating: train/raw_data/0/804.jpg
#   inflating: train/raw_data/0/805.jpg
#   inflating: train/raw_data/0/806.jpg
#   inflating: train/raw_data/0/807.jpg
#   inflating: train/raw_data/0/808.jpg
#   inflating: train/raw_data/0/809.jpg
#   inflating: train/raw_data/0/80.jpg
#   inflating: train/raw_data/0/810.jpg
#   inflating: train/raw_data/0/811.jpg
#   inflating: train/raw_data/0/812.jpg
#   inflating: train/raw_data/0/813.jpg
#   inflating: train/raw_data/0/814.jpg
#   inflating: train/raw_data/0/815.jpg
#   inflating: train/raw_data/0/816.jpg
#   inflating: train/raw_data/0/817.jpg
#   inflating: train/raw_data/0/818.jpg
#   inflating: train/raw_data/0/819.jpg
#   inflating: train/raw_data/0/81.jpg
#   inflating: train/raw_data/0/820.jpg
#   inflating: train/raw_data/0/821.jpg
#   inflating: train/raw_data/0/822.jpg
#   inflating: train/raw_data/0/823.jpg
#   inflating: train/raw_data/0/824.jpg
#   inflating: train/raw_data/0/825.jpg
#   inflating: train/raw_data/0/826.jpg
#   inflating: train/raw_data/0/827.jpg
#   inflating: train/raw_data/0/828.jpg
#   inflating: train/raw_data/0/829.jpg
#   inflating: train/raw_data/0/82.jpg
#   inflating: train/raw_data/0/830.jpg
#   inflating: train/raw_data/0/831.jpg
#   inflating: train/raw_data/0/832.jpg
#   inflating: train/raw_data/0/833.jpg
#   inflating: train/raw_data/0/834.jpg
#   inflating: train/raw_data/0/835.jpg
#   inflating: train/raw_data/0/836.jpg
#   inflating: train/raw_data/0/837.jpg
#   inflating: train/raw_data/0/838.jpg
#   inflating: train/raw_data/0/839.jpg
#   inflating: train/raw_data/0/83.jpg
#   inflating: train/raw_data/0/840.jpg
#   inflating: train/raw_data/0/841.jpg
#   inflating: train/raw_data/0/842.jpg
#   inflating: train/raw_data/0/843.jpg
#   inflating: train/raw_data/0/844.jpg
#   inflating: train/raw_data/0/845.jpg
#   inflating: train/raw_data/0/846.jpg
#   inflating: train/raw_data/0/847.jpg
#   inflating: train/raw_data/0/848.jpg
#   inflating: train/raw_data/0/849.jpg
#   inflating: train/raw_data/0/84.jpg
#   inflating: train/raw_data/0/850.jpg
#   inflating: train/raw_data/0/851.jpg
#   inflating: train/raw_data/0/852.jpg
#   inflating: train/raw_data/0/853.jpg
#   inflating: train/raw_data/0/854.jpg
#   inflating: train/raw_data/0/855.jpg
#   inflating: train/raw_data/0/856.jpg
#   inflating: train/raw_data/0/857.jpg
#   inflating: train/raw_data/0/858.jpg
#   inflating: train/raw_data/0/859.jpg
#   inflating: train/raw_data/0/85.jpg
#   inflating: train/raw_data/0/860.jpg
#   inflating: train/raw_data/0/861.jpg
#   inflating: train/raw_data/0/862.jpg
#   inflating: train/raw_data/0/863.jpg
#   inflating: train/raw_data/0/864.jpg
#   inflating: train/raw_data/0/865.jpg
#   inflating: train/raw_data/0/866.jpg
#   inflating: train/raw_data/0/867.jpg
#   inflating: train/raw_data/0/868.jpg
#   inflating: train/raw_data/0/869.jpg
#   inflating: train/raw_data/0/86.jpg
#   inflating: train/raw_data/0/870.jpg
#   inflating: train/raw_data/0/871.jpg
#   inflating: train/raw_data/0/872.jpg
#   inflating: train/raw_data/0/873.jpg
#   inflating: train/raw_data/0/874.jpg
#   inflating: train/raw_data/0/875.jpg
#   inflating: train/raw_data/0/876.jpg
#   inflating: train/raw_data/0/877.jpg
#   inflating: train/raw_data/0/878.jpg
#   inflating: train/raw_data/0/879.jpg
#   inflating: train/raw_data/0/87.jpg
#   inflating: train/raw_data/0/880.jpg
#   inflating: train/raw_data/0/881.jpg
#   inflating: train/raw_data/0/882.jpg
#   inflating: train/raw_data/0/883.jpg
#   inflating: train/raw_data/0/884.jpg
#   inflating: train/raw_data/0/885.jpg
#   inflating: train/raw_data/0/886.jpg
#   inflating: train/raw_data/0/887.jpg
#   inflating: train/raw_data/0/888.jpg
#   inflating: train/raw_data/0/889.jpg
#   inflating: train/raw_data/0/88.jpg
#   inflating: train/raw_data/0/890.jpg
#   inflating: train/raw_data/0/891.jpg
#   inflating: train/raw_data/0/892.jpg
#   inflating: train/raw_data/0/893.jpg
#   inflating: train/raw_data/0/894.jpg
#   inflating: train/raw_data/0/895.jpg
#   inflating: train/raw_data/0/896.jpg
#   inflating: train/raw_data/0/897.jpg
#   inflating: train/raw_data/0/898.jpg
#   inflating: train/raw_data/0/899.jpg
#   inflating: train/raw_data/0/89.jpg
#   inflating: train/raw_data/0/8.jpg
#   inflating: train/raw_data/0/900.jpg
#   inflating: train/raw_data/0/901.jpg
#   inflating: train/raw_data/0/902.jpg
#   inflating: train/raw_data/0/903.jpg
#   inflating: train/raw_data/0/904.jpg
#   inflating: train/raw_data/0/905.jpg
#   inflating: train/raw_data/0/906.jpg
#   inflating: train/raw_data/0/907.jpg
#   inflating: train/raw_data/0/908.jpg
#   inflating: train/raw_data/0/909.jpg
#   inflating: train/raw_data/0/90.jpg
#   inflating: train/raw_data/0/910.jpg
#   inflating: train/raw_data/0/911.jpg
#   inflating: train/raw_data/0/912.jpg
#   inflating: train/raw_data/0/913.jpg
#   inflating: train/raw_data/0/914.jpg
#   inflating: train/raw_data/0/915.jpg
#   inflating: train/raw_data/0/916.jpg
#   inflating: train/raw_data/0/917.jpg
#   inflating: train/raw_data/0/918.jpg
#   inflating: train/raw_data/0/919.jpg
#   inflating: train/raw_data/0/91.jpg
#   inflating: train/raw_data/0/920.jpg
#   inflating: train/raw_data/0/921.jpg
#   inflating: train/raw_data/0/922.jpg
#   inflating: train/raw_data/0/923.jpg
#   inflating: train/raw_data/0/924.jpg
#   inflating: train/raw_data/0/925.jpg
#   inflating: train/raw_data/0/926.jpg
#   inflating: train/raw_data/0/927.jpg
#   inflating: train/raw_data/0/928.jpg
#   inflating: train/raw_data/0/929.jpg
#   inflating: train/raw_data/0/92.jpg
#   inflating: train/raw_data/0/930.jpg
#   inflating: train/raw_data/0/931.jpg
#   inflating: train/raw_data/0/932.jpg
#   inflating: train/raw_data/0/933.jpg
#   inflating: train/raw_data/0/934.jpg
#   inflating: train/raw_data/0/935.jpg
#   inflating: train/raw_data/0/936.jpg
#   inflating: train/raw_data/0/937.jpg
#   inflating: train/raw_data/0/938.jpg
#   inflating: train/raw_data/0/939.jpg
#   inflating: train/raw_data/0/93.jpg
#   inflating: train/raw_data/0/940.jpg
#   inflating: train/raw_data/0/941.jpg
#   inflating: train/raw_data/0/942.jpg
#   inflating: train/raw_data/0/943.jpg
#   inflating: train/raw_data/0/944.jpg
#   inflating: train/raw_data/0/945.jpg
#   inflating: train/raw_data/0/946.jpg
#   inflating: train/raw_data/0/947.jpg
#   inflating: train/raw_data/0/948.jpg
#   inflating: train/raw_data/0/949.jpg
#   inflating: train/raw_data/0/94.jpg
#   inflating: train/raw_data/0/950.jpg
#   inflating: train/raw_data/0/951.jpg
#   inflating: train/raw_data/0/952.jpg
#   inflating: train/raw_data/0/953.jpg
#   inflating: train/raw_data/0/954.jpg
#   inflating: train/raw_data/0/955.jpg
#   inflating: train/raw_data/0/956.jpg
#   inflating: train/raw_data/0/957.jpg
#   inflating: train/raw_data/0/958.jpg
#   inflating: train/raw_data/0/959.jpg
#   inflating: train/raw_data/0/95.jpg
#   inflating: train/raw_data/0/960.jpg
#   inflating: train/raw_data/0/961.jpg
#   inflating: train/raw_data/0/962.jpg
#   inflating: train/raw_data/0/963.jpg
#   inflating: train/raw_data/0/964.jpg
#   inflating: train/raw_data/0/965.jpg
#   inflating: train/raw_data/0/966.jpg
#   inflating: train/raw_data/0/967.jpg
#   inflating: train/raw_data/0/968.jpg
#   inflating: train/raw_data/0/969.jpg
#   inflating: train/raw_data/0/96.jpg
#   inflating: train/raw_data/0/970.jpg
#   inflating: train/raw_data/0/971.jpg
#   inflating: train/raw_data/0/972.jpg
#   inflating: train/raw_data/0/973.jpg
#   inflating: train/raw_data/0/974.jpg
#   inflating: train/raw_data/0/975.jpg
#   inflating: train/raw_data/0/976.jpg
#   inflating: train/raw_data/0/977.jpg
#   inflating: train/raw_data/0/978.jpg
#   inflating: train/raw_data/0/979.jpg
#   inflating: train/raw_data/0/97.jpg
#   inflating: train/raw_data/0/980.jpg
#   inflating: train/raw_data/0/981.jpg
#   inflating: train/raw_data/0/982.jpg
#   inflating: train/raw_data/0/983.jpg
#   inflating: train/raw_data/0/984.jpg
#   inflating: train/raw_data/0/985.jpg
#   inflating: train/raw_data/0/986.jpg
#   inflating: train/raw_data/0/987.jpg
#   inflating: train/raw_data/0/988.jpg
#   inflating: train/raw_data/0/989.jpg
#   inflating: train/raw_data/0/98.jpg
#   inflating: train/raw_data/0/990.jpg
#   inflating: train/raw_data/0/991.jpg
#   inflating: train/raw_data/0/992.jpg
#   inflating: train/raw_data/0/993.jpg
#   inflating: train/raw_data/0/994.jpg
#   inflating: train/raw_data/0/995.jpg
#   inflating: train/raw_data/0/996.jpg
#   inflating: train/raw_data/0/997.jpg
#   inflating: train/raw_data/0/998.jpg
#   inflating: train/raw_data/0/999.jpg
#   inflating: train/raw_data/0/99.jpg
#   inflating: train/raw_data/0/9.jpg
#   inflating: train/raw_data/1/0.jpg
#   inflating: train/raw_data/1/1000.jpg
#   inflating: train/raw_data/1/1001.jpg
#   inflating: train/raw_data/1/1002.jpg
#   inflating: train/raw_data/1/1003.jpg
#   inflating: train/raw_data/1/1004.jpg
#   inflating: train/raw_data/1/1005.jpg
#   inflating: train/raw_data/1/1006.jpg
#   inflating: train/raw_data/1/1007.jpg
#   inflating: train/raw_data/1/1008.jpg
#   inflating: train/raw_data/1/1009.jpg
#   inflating: train/raw_data/1/100.jpg
#   inflating: train/raw_data/1/1010.jpg
#   inflating: train/raw_data/1/1011.jpg
#   inflating: train/raw_data/1/1012.jpg
#   inflating: train/raw_data/1/1013.jpg
#   inflating: train/raw_data/1/1014.jpg
#   inflating: train/raw_data/1/1015.jpg
#   inflating: train/raw_data/1/1016.jpg
#   inflating: train/raw_data/1/1017.jpg
#   inflating: train/raw_data/1/1018.jpg
#   inflating: train/raw_data/1/1019.jpg
#   inflating: train/raw_data/1/101.jpg
#   inflating: train/raw_data/1/1020.jpg
#   inflating: train/raw_data/1/1021.jpg
#   inflating: train/raw_data/1/1022.jpg
#   inflating: train/raw_data/1/1023.jpg
#   inflating: train/raw_data/1/1024.jpg
#   inflating: train/raw_data/1/1025.jpg
#   inflating: train/raw_data/1/1026.jpg
#   inflating: train/raw_data/1/1027.jpg
#   inflating: train/raw_data/1/1028.jpg
#   inflating: train/raw_data/1/1029.jpg
#   inflating: train/raw_data/1/102.jpg
#   inflating: train/raw_data/1/1030.jpg
#   inflating: train/raw_data/1/1031.jpg
#   inflating: train/raw_data/1/1032.jpg
#   inflating: train/raw_data/1/1033.jpg
#   inflating: train/raw_data/1/1034.jpg
#   inflating: train/raw_data/1/1035.jpg
#   inflating: train/raw_data/1/1036.jpg
#   inflating: train/raw_data/1/1037.jpg
#   inflating: train/raw_data/1/1038.jpg
#   inflating: train/raw_data/1/1039.jpg
#   inflating: train/raw_data/1/103.jpg
#   inflating: train/raw_data/1/1040.jpg
#   inflating: train/raw_data/1/1041.jpg
#   inflating: train/raw_data/1/1042.jpg
#   inflating: train/raw_data/1/1043.jpg
#   inflating: train/raw_data/1/1044.jpg
#   inflating: train/raw_data/1/1045.jpg
#   inflating: train/raw_data/1/1046.jpg
#   inflating: train/raw_data/1/1047.jpg
#   inflating: train/raw_data/1/1048.jpg
#   inflating: train/raw_data/1/1049.jpg
#   inflating: train/raw_data/1/104.jpg
#   inflating: train/raw_data/1/1050.jpg
#   inflating: train/raw_data/1/1051.jpg
#   inflating: train/raw_data/1/1052.jpg
#   inflating: train/raw_data/1/1053.jpg
#   inflating: train/raw_data/1/1054.jpg
#   inflating: train/raw_data/1/1055.jpg
#   inflating: train/raw_data/1/1056.jpg
#   inflating: train/raw_data/1/1057.jpg
#   inflating: train/raw_data/1/1058.jpg
#   inflating: train/raw_data/1/1059.jpg
#   inflating: train/raw_data/1/105.jpg
#   inflating: train/raw_data/1/1060.jpg
#   inflating: train/raw_data/1/1061.jpg
#   inflating: train/raw_data/1/1062.jpg
#   inflating: train/raw_data/1/1063.jpg
#   inflating: train/raw_data/1/1064.jpg
#   inflating: train/raw_data/1/1065.jpg
#   inflating: train/raw_data/1/1066.jpg
#   inflating: train/raw_data/1/1067.jpg
#   inflating: train/raw_data/1/1068.jpg
#   inflating: train/raw_data/1/1069.jpg
#   inflating: train/raw_data/1/106.jpg
#   inflating: train/raw_data/1/1070.jpg
#   inflating: train/raw_data/1/1071.jpg
#   inflating: train/raw_data/1/1072.jpg
#   inflating: train/raw_data/1/1073.jpg
#   inflating: train/raw_data/1/1074.jpg
#   inflating: train/raw_data/1/1075.jpg
#   inflating: train/raw_data/1/1076.jpg
#   inflating: train/raw_data/1/1077.jpg
#   inflating: train/raw_data/1/1078.jpg
#   inflating: train/raw_data/1/1079.jpg
#   inflating: train/raw_data/1/107.jpg
#   inflating: train/raw_data/1/1080.jpg
#   inflating: train/raw_data/1/1081.jpg
#   inflating: train/raw_data/1/1082.jpg
#   inflating: train/raw_data/1/1083.jpg
#   inflating: train/raw_data/1/1084.jpg
#   inflating: train/raw_data/1/1085.jpg
#   inflating: train/raw_data/1/1086.jpg
#   inflating: train/raw_data/1/1087.jpg
#   inflating: train/raw_data/1/1088.jpg
#   inflating: train/raw_data/1/1089.jpg
#   inflating: train/raw_data/1/108.jpg
#   inflating: train/raw_data/1/1090.jpg
#   inflating: train/raw_data/1/1091.jpg
#   inflating: train/raw_data/1/1092.jpg
#   inflating: train/raw_data/1/1093.jpg
#   inflating: train/raw_data/1/1094.jpg
#   inflating: train/raw_data/1/1095.jpg
#   inflating: train/raw_data/1/1096.jpg
#   inflating: train/raw_data/1/1097.jpg
#   inflating: train/raw_data/1/1098.jpg
#   inflating: train/raw_data/1/1099.jpg
#   inflating: train/raw_data/1/109.jpg
#   inflating: train/raw_data/1/10.jpg
#   inflating: train/raw_data/1/1100.jpg
#   inflating: train/raw_data/1/1101.jpg
#   inflating: train/raw_data/1/1102.jpg
#   inflating: train/raw_data/1/1103.jpg
#   inflating: train/raw_data/1/1104.jpg
#   inflating: train/raw_data/1/1105.jpg
#   inflating: train/raw_data/1/1106.jpg
#   inflating: train/raw_data/1/1107.jpg
#   inflating: train/raw_data/1/1108.jpg
#   inflating: train/raw_data/1/1109.jpg
#   inflating: train/raw_data/1/110.jpg
#   inflating: train/raw_data/1/1110.jpg
#   inflating: train/raw_data/1/1111.jpg
#   inflating: train/raw_data/1/1112.jpg
#   inflating: train/raw_data/1/1113.jpg
#   inflating: train/raw_data/1/1114.jpg
#   inflating: train/raw_data/1/1115.jpg
#   inflating: train/raw_data/1/1116.jpg
#   inflating: train/raw_data/1/1117.jpg
#   inflating: train/raw_data/1/1118.jpg
#   inflating: train/raw_data/1/1119.jpg
#   inflating: train/raw_data/1/111.jpg
#   inflating: train/raw_data/1/1120.jpg
#   inflating: train/raw_data/1/1121.jpg
#   inflating: train/raw_data/1/1122.jpg
#   inflating: train/raw_data/1/1123.jpg
#   inflating: train/raw_data/1/1124.jpg
#   inflating: train/raw_data/1/1125.jpg
#   inflating: train/raw_data/1/1126.jpg
#   inflating: train/raw_data/1/1127.jpg
#   inflating: train/raw_data/1/1128.jpg
#   inflating: train/raw_data/1/1129.jpg
# ...
#   inflating: train/raw_data/1/63.jpg
#   inflating: train/raw_data/1/640.jpg
#   inflating: train/raw_data/1/641.jpg
#   inflating: train/raw_data/1/642.jpg
#   inflating: train/raw_data/1/643.jpg
#   inflating: train/raw_data/1/644.jpg
#   inflating: train/raw_data/1/645.jpg
#   inflating: train/raw_data/1/646.jpg
#   inflating: train/raw_data/1/647.jpg
#   inflating: train/raw_data/1/648.jpg
#   inflating: train/raw_data/1/649.jpg
#   inflating: train/raw_data/1/64.jpg
#   inflating: train/raw_data/1/650.jpg
#   inflating: train/raw_data/1/651.jpg
#   inflating: train/raw_data/1/652.jpg
#   inflating: train/raw_data/1/653.jpg
#   inflating: train/raw_data/1/654.jpg
#   inflating: train/raw_data/1/655.jpg
#   inflating: train/raw_data/1/656.jpg
#   inflating: train/raw_data/1/657.jpg
#   inflating: train/raw_data/1/658.jpg
#   inflating: train/raw_data/1/659.jpg
#   inflating: train/raw_data/1/65.jpg
#   inflating: train/raw_data/1/660.jpg
#   inflating: train/raw_data/1/661.jpg
#   inflating: train/raw_data/1/662.jpg
#   inflating: train/raw_data/1/663.jpg
#   inflating: train/raw_data/1/664.jpg
#   inflating: train/raw_data/1/665.jpg
#   inflating: train/raw_data/1/666.jpg
#   inflating: train/raw_data/1/667.jpg
#   inflating: train/raw_data/1/668.jpg
#   inflating: train/raw_data/1/669.jpg
#   inflating: train/raw_data/1/66.jpg
#   inflating: train/raw_data/1/670.jpg
#   inflating: train/raw_data/1/671.jpg
#   inflating: train/raw_data/1/672.jpg
#   inflating: train/raw_data/1/673.jpg
#   inflating: train/raw_data/1/674.jpg
#   inflating: train/raw_data/1/675.jpg
#   inflating: train/raw_data/1/676.jpg
#   inflating: train/raw_data/1/677.jpg
#   inflating: train/raw_data/1/678.jpg
#   inflating: train/raw_data/1/679.jpg
#   inflating: train/raw_data/1/67.jpg
#   inflating: train/raw_data/1/680.jpg
#   inflating: train/raw_data/1/681.jpg
#   inflating: train/raw_data/1/682.jpg
#   inflating: train/raw_data/1/683.jpg
#   inflating: train/raw_data/1/684.jpg
#   inflating: train/raw_data/1/685.jpg
#   inflating: train/raw_data/1/686.jpg
#   inflating: train/raw_data/1/687.jpg
#   inflating: train/raw_data/1/688.jpg
#   inflating: train/raw_data/1/689.jpg
#   inflating: train/raw_data/1/68.jpg
#   inflating: train/raw_data/1/690.jpg
#   inflating: train/raw_data/1/691.jpg
#   inflating: train/raw_data/1/692.jpg
#   inflating: train/raw_data/1/693.jpg
#   inflating: train/raw_data/1/694.jpg
#   inflating: train/raw_data/1/695.jpg
#   inflating: train/raw_data/1/696.jpg
#   inflating: train/raw_data/1/697.jpg
#   inflating: train/raw_data/1/698.jpg
#   inflating: train/raw_data/1/699.jpg
#   inflating: train/raw_data/1/69.jpg
#   inflating: train/raw_data/1/6.jpg
#   inflating: train/raw_data/1/700.jpg
#   inflating: train/raw_data/1/701.jpg
#   inflating: train/raw_data/1/702.jpg
#   inflating: train/raw_data/1/703.jpg
#   inflating: train/raw_data/1/704.jpg
#   inflating: train/raw_data/1/705.jpg
#   inflating: train/raw_data/1/706.jpg
#   inflating: train/raw_data/1/707.jpg
#   inflating: train/raw_data/1/708.jpg
#   inflating: train/raw_data/1/709.jpg
#   inflating: train/raw_data/1/70.jpg
#   inflating: train/raw_data/1/710.jpg
#   inflating: train/raw_data/1/711.jpg
#   inflating: train/raw_data/1/712.jpg
#   inflating: train/raw_data/1/713.jpg
#   inflating: train/raw_data/1/714.jpg
#   inflating: train/raw_data/1/715.jpg
#   inflating: train/raw_data/1/716.jpg
#   inflating: train/raw_data/1/717.jpg
#   inflating: train/raw_data/1/718.jpg
#   inflating: train/raw_data/1/719.jpg
#   inflating: train/raw_data/1/71.jpg
#   inflating: train/raw_data/1/720.jpg
#   inflating: train/raw_data/1/721.jpg
#   inflating: train/raw_data/1/722.jpg
#   inflating: train/raw_data/1/723.jpg
#   inflating: train/raw_data/1/724.jpg
#   inflating: train/raw_data/1/725.jpg
#   inflating: train/raw_data/1/726.jpg
#   inflating: train/raw_data/1/727.jpg
#   inflating: train/raw_data/1/728.jpg
#   inflating: train/raw_data/1/729.jpg
#   inflating: train/raw_data/1/72.jpg
#   inflating: train/raw_data/1/730.jpg
#   inflating: train/raw_data/1/731.jpg
#   inflating: train/raw_data/1/732.jpg
#   inflating: train/raw_data/1/733.jpg
#   inflating: train/raw_data/1/734.jpg
#   inflating: train/raw_data/1/735.jpg
#   inflating: train/raw_data/1/736.jpg
#   inflating: train/raw_data/1/737.jpg
#   inflating: train/raw_data/1/738.jpg
#   inflating: train/raw_data/1/739.jpg
#   inflating: train/raw_data/1/73.jpg
#   inflating: train/raw_data/1/740.jpg
#   inflating: train/raw_data/1/741.jpg
#   inflating: train/raw_data/1/742.jpg
#   inflating: train/raw_data/1/743.jpg
#   inflating: train/raw_data/1/744.jpg
#   inflating: train/raw_data/1/745.jpg
#   inflating: train/raw_data/1/746.jpg
#   inflating: train/raw_data/1/747.jpg
#   inflating: train/raw_data/1/748.jpg
#   inflating: train/raw_data/1/749.jpg
#   inflating: train/raw_data/1/74.jpg
#   inflating: train/raw_data/1/750.jpg
#   inflating: train/raw_data/1/751.jpg
#   inflating: train/raw_data/1/752.jpg
#   inflating: train/raw_data/1/753.jpg
#   inflating: train/raw_data/1/754.jpg
#   inflating: train/raw_data/1/755.jpg
#   inflating: train/raw_data/1/756.jpg
#   inflating: train/raw_data/1/757.jpg
#   inflating: train/raw_data/1/758.jpg
#   inflating: train/raw_data/1/759.jpg
#   inflating: train/raw_data/1/75.jpg
#   inflating: train/raw_data/1/760.jpg
#   inflating: train/raw_data/1/761.jpg
#   inflating: train/raw_data/1/762.jpg
#   inflating: train/raw_data/1/763.jpg
#   inflating: train/raw_data/1/764.jpg
#   inflating: train/raw_data/1/765.jpg
#   inflating: train/raw_data/1/766.jpg
#   inflating: train/raw_data/1/767.jpg
#   inflating: train/raw_data/1/768.jpg
#   inflating: train/raw_data/1/769.jpg
#   inflating: train/raw_data/1/76.jpg
#   inflating: train/raw_data/1/770.jpg
#   inflating: train/raw_data/1/771.jpg
#   inflating: train/raw_data/1/772.jpg
#   inflating: train/raw_data/1/773.jpg
#   inflating: train/raw_data/1/774.jpg
#   inflating: train/raw_data/1/775.jpg
#   inflating: train/raw_data/1/776.jpg
#   inflating: train/raw_data/1/777.jpg
#   inflating: train/raw_data/1/778.jpg
#   inflating: train/raw_data/1/779.jpg
#   inflating: train/raw_data/1/77.jpg
#   inflating: train/raw_data/1/780.jpg
#   inflating: train/raw_data/1/781.jpg
#   inflating: train/raw_data/1/782.jpg
#   inflating: train/raw_data/1/783.jpg
#   inflating: train/raw_data/1/784.jpg
#   inflating: train/raw_data/1/785.jpg
#   inflating: train/raw_data/1/786.jpg
#   inflating: train/raw_data/1/787.jpg
#   inflating: train/raw_data/1/788.jpg
#   inflating: train/raw_data/1/789.jpg
#   inflating: train/raw_data/1/78.jpg
#   inflating: train/raw_data/1/790.jpg
#   inflating: train/raw_data/1/791.jpg
#   inflating: train/raw_data/1/792.jpg
#   inflating: train/raw_data/1/793.jpg
#   inflating: train/raw_data/1/794.jpg
#   inflating: train/raw_data/1/795.jpg
#   inflating: train/raw_data/1/796.jpg
#   inflating: train/raw_data/1/797.jpg
#   inflating: train/raw_data/1/798.jpg
#   inflating: train/raw_data/1/799.jpg
#   inflating: train/raw_data/1/79.jpg
#   inflating: train/raw_data/1/7.jpg
#   inflating: train/raw_data/1/800.jpg
#   inflating: train/raw_data/1/801.jpg
#   inflating: train/raw_data/1/802.jpg
#   inflating: train/raw_data/1/803.jpg
#   inflating: train/raw_data/1/804.jpg
#   inflating: train/raw_data/1/805.jpg
#   inflating: train/raw_data/1/806.jpg
#   inflating: train/raw_data/1/807.jpg
#   inflating: train/raw_data/1/808.jpg
#   inflating: train/raw_data/1/809.jpg
#   inflating: train/raw_data/1/80.jpg
#   inflating: train/raw_data/1/810.jpg
#   inflating: train/raw_data/1/811.jpg
#   inflating: train/raw_data/1/812.jpg
#   inflating: train/raw_data/1/813.jpg
#   inflating: train/raw_data/1/814.jpg
#   inflating: train/raw_data/1/815.jpg
#   inflating: train/raw_data/1/816.jpg
#   inflating: train/raw_data/1/817.jpg
#   inflating: train/raw_data/1/818.jpg
#   inflating: train/raw_data/1/819.jpg
#   inflating: train/raw_data/1/81.jpg
#   inflating: train/raw_data/1/820.jpg
#   inflating: train/raw_data/1/821.jpg
#   inflating: train/raw_data/1/822.jpg
#   inflating: train/raw_data/1/823.jpg
#   inflating: train/raw_data/1/824.jpg
#   inflating: train/raw_data/1/825.jpg
#   inflating: train/raw_data/1/826.jpg
#   inflating: train/raw_data/1/827.jpg
#   inflating: train/raw_data/1/828.jpg
#   inflating: train/raw_data/1/829.jpg
#   inflating: train/raw_data/1/82.jpg
#   inflating: train/raw_data/1/830.jpg
#   inflating: train/raw_data/1/831.jpg
#   inflating: train/raw_data/1/832.jpg
#   inflating: train/raw_data/1/833.jpg
#   inflating: train/raw_data/1/834.jpg
#   inflating: train/raw_data/1/835.jpg
#   inflating: train/raw_data/1/836.jpg
#   inflating: train/raw_data/1/837.jpg
#   inflating: train/raw_data/1/838.jpg
#   inflating: train/raw_data/1/839.jpg
#   inflating: train/raw_data/1/83.jpg
#   inflating: train/raw_data/1/840.jpg
#   inflating: train/raw_data/1/841.jpg
#   inflating: train/raw_data/1/842.jpg
#   inflating: train/raw_data/1/843.jpg
#   inflating: train/raw_data/1/844.jpg
#   inflating: train/raw_data/1/845.jpg
#   inflating: train/raw_data/1/846.jpg
#   inflating: train/raw_data/1/847.jpg
#   inflating: train/raw_data/1/848.jpg
#   inflating: train/raw_data/1/849.jpg
#   inflating: train/raw_data/1/84.jpg
#   inflating: train/raw_data/1/850.jpg
#   inflating: train/raw_data/1/851.jpg
#   inflating: train/raw_data/1/852.jpg
#   inflating: train/raw_data/1/853.jpg
#   inflating: train/raw_data/1/854.jpg
#   inflating: train/raw_data/1/855.jpg
#   inflating: train/raw_data/1/856.jpg
#   inflating: train/raw_data/1/857.jpg
#   inflating: train/raw_data/1/858.jpg
#   inflating: train/raw_data/1/859.jpg
#   inflating: train/raw_data/1/85.jpg
#   inflating: train/raw_data/1/860.jpg
#   inflating: train/raw_data/1/861.jpg
#   inflating: train/raw_data/1/862.jpg
#   inflating: train/raw_data/1/863.jpg
#   inflating: train/raw_data/1/864.jpg
#   inflating: train/raw_data/1/865.jpg
#   inflating: train/raw_data/1/866.jpg
#   inflating: train/raw_data/1/867.jpg
#   inflating: train/raw_data/1/868.jpg
#   inflating: train/raw_data/1/869.jpg
#   inflating: train/raw_data/1/86.jpg
#   inflating: train/raw_data/1/870.jpg
#   inflating: train/raw_data/1/871.jpg
#   inflating: train/raw_data/1/872.jpg
#   inflating: train/raw_data/1/873.jpg
#   inflating: train/raw_data/1/874.jpg
#   inflating: train/raw_data/1/875.jpg
#   inflating: train/raw_data/1/876.jpg
#   inflating: train/raw_data/1/877.jpg
#   inflating: train/raw_data/1/878.jpg
#   inflating: train/raw_data/1/879.jpg
#   inflating: train/raw_data/1/87.jpg
#   inflating: train/raw_data/1/880.jpg
#   inflating: train/raw_data/1/881.jpg
#   inflating: train/raw_data/1/882.jpg
#   inflating: train/raw_data/1/883.jpg
#   inflating: train/raw_data/1/884.jpg
#   inflating: train/raw_data/1/885.jpg
#   inflating: train/raw_data/1/886.jpg
#   inflating: train/raw_data/1/887.jpg
#   inflating: train/raw_data/1/888.jpg
#   inflating: train/raw_data/1/889.jpg
#   inflating: train/raw_data/1/88.jpg
#   inflating: train/raw_data/1/890.jpg
#   inflating: train/raw_data/1/891.jpg
#   inflating: train/raw_data/1/892.jpg
#   inflating: train/raw_data/1/893.jpg
#   inflating: train/raw_data/1/894.jpg
#   inflating: train/raw_data/1/895.jpg
#   inflating: train/raw_data/1/896.jpg
#   inflating: train/raw_data/1/897.jpg
#   inflating: train/raw_data/1/898.jpg
#   inflating: train/raw_data/1/899.jpg
#   inflating: train/raw_data/1/89.jpg
#   inflating: train/raw_data/1/8.jpg
#   inflating: train/raw_data/1/900.jpg
#   inflating: train/raw_data/1/901.jpg
#   inflating: train/raw_data/1/902.jpg
#   inflating: train/raw_data/1/903.jpg
#   inflating: train/raw_data/1/904.jpg
#   inflating: train/raw_data/1/905.jpg
#   inflating: train/raw_data/1/906.jpg
#   inflating: train/raw_data/1/907.jpg
#   inflating: train/raw_data/1/908.jpg
#   inflating: train/raw_data/1/909.jpg
#   inflating: train/raw_data/1/90.jpg
#   inflating: train/raw_data/1/910.jpg
#   inflating: train/raw_data/1/911.jpg
#   inflating: train/raw_data/1/912.jpg
#   inflating: train/raw_data/1/913.jpg
#   inflating: train/raw_data/1/914.jpg
#   inflating: train/raw_data/1/915.jpg
#   inflating: train/raw_data/1/916.jpg
#   inflating: train/raw_data/1/917.jpg
#   inflating: train/raw_data/1/918.jpg
#   inflating: train/raw_data/1/919.jpg
#   inflating: train/raw_data/1/91.jpg
#   inflating: train/raw_data/1/920.jpg
#   inflating: train/raw_data/1/921.jpg
#   inflating: train/raw_data/1/922.jpg
#   inflating: train/raw_data/1/923.jpg
#   inflating: train/raw_data/1/924.jpg
#   inflating: train/raw_data/1/925.jpg
#   inflating: train/raw_data/1/926.jpg
#   inflating: train/raw_data/1/927.jpg
#   inflating: train/raw_data/1/928.jpg
#   inflating: train/raw_data/1/929.jpg
#   inflating: train/raw_data/1/92.jpg
#   inflating: train/raw_data/1/930.jpg
#   inflating: train/raw_data/1/931.jpg
#   inflating: train/raw_data/1/932.jpg
#   inflating: train/raw_data/1/933.jpg
#   inflating: train/raw_data/1/934.jpg
#   inflating: train/raw_data/1/935.jpg
#   inflating: train/raw_data/1/936.jpg
#   inflating: train/raw_data/1/937.jpg
#   inflating: train/raw_data/1/938.jpg
#   inflating: train/raw_data/1/939.jpg
#   inflating: train/raw_data/1/93.jpg
#   inflating: train/raw_data/1/940.jpg
#   inflating: train/raw_data/1/941.jpg
#   inflating: train/raw_data/1/942.jpg
#   inflating: train/raw_data/1/943.jpg
#   inflating: train/raw_data/1/944.jpg
#   inflating: train/raw_data/1/945.jpg
#   inflating: train/raw_data/1/946.jpg
#   inflating: train/raw_data/1/947.jpg
#   inflating: train/raw_data/1/948.jpg
#   inflating: train/raw_data/1/949.jpg
#   inflating: train/raw_data/1/94.jpg
#   inflating: train/raw_data/1/950.jpg
#   inflating: train/raw_data/1/951.jpg
#   inflating: train/raw_data/1/952.jpg
#   inflating: train/raw_data/1/953.jpg
#   inflating: train/raw_data/1/954.jpg
#   inflating: train/raw_data/1/955.jpg
#   inflating: train/raw_data/1/956.jpg
#   inflating: train/raw_data/1/957.jpg
#   inflating: train/raw_data/1/958.jpg
#   inflating: train/raw_data/1/959.jpg
#   inflating: train/raw_data/1/95.jpg
#   inflating: train/raw_data/1/960.jpg
#   inflating: train/raw_data/1/961.jpg
#   inflating: train/raw_data/1/962.jpg
#   inflating: train/raw_data/1/963.jpg
#   inflating: train/raw_data/1/964.jpg
#   inflating: train/raw_data/1/965.jpg
#   inflating: train/raw_data/1/966.jpg
#   inflating: train/raw_data/1/967.jpg
#   inflating: train/raw_data/1/968.jpg
#   inflating: train/raw_data/1/969.jpg
#   inflating: train/raw_data/1/96.jpg
#   inflating: train/raw_data/1/970.jpg
#   inflating: train/raw_data/1/971.jpg
#   inflating: train/raw_data/1/972.jpg
#   inflating: train/raw_data/1/973.jpg
#   inflating: train/raw_data/1/974.jpg
#   inflating: train/raw_data/1/975.jpg
#   inflating: train/raw_data/1/976.jpg
#   inflating: train/raw_data/1/977.jpg
#   inflating: train/raw_data/1/978.jpg
#   inflating: train/raw_data/1/979.jpg
#   inflating: train/raw_data/1/97.jpg
#   inflating: train/raw_data/1/980.jpg
#   inflating: train/raw_data/1/981.jpg
#   inflating: train/raw_data/1/982.jpg
#   inflating: train/raw_data/1/983.jpg
#   inflating: train/raw_data/1/984.jpg
#   inflating: train/raw_data/1/985.jpg
#   inflating: train/raw_data/1/986.jpg
#   inflating: train/raw_data/1/987.jpg
#   inflating: train/raw_data/1/988.jpg
#   inflating: train/raw_data/1/989.jpg
#   inflating: train/raw_data/1/98.jpg
#   inflating: train/raw_data/1/990.jpg
#   inflating: train/raw_data/1/991.jpg
#   inflating: train/raw_data/1/992.jpg
#   inflating: train/raw_data/1/993.jpg
#   inflating: train/raw_data/1/994.jpg
#   inflating: train/raw_data/1/995.jpg
#   inflating: train/raw_data/1/996.jpg
#   inflating: train/raw_data/1/997.jpg
#   inflating: train/raw_data/1/998.jpg
#   inflating: train/raw_data/1/999.jpg
#   inflating: train/raw_data/1/99.jpg
#   inflating: train/raw_data/1/9.jpg

# %%
# !pip install split-folders
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting split-folders
#   Downloading split_folders-0.5.1-py3-none-any.whl (8.4 kB)
# Installing collected packages: split-folders
# Successfully installed split-folders-0.5.1

# %%
import splitfolders
splitfolders.ratio('/content/train/raw_data', output="output", seed=1337, ratio=(.6, 0.2,0.2))
# Out:
# Copying files: 7659 files [00:07, 1087.92 files/s]

# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load in 

from __future__ import absolute_import, division, print_function, unicode_literals

import os
import glob
import shutil

import cv2
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
import seaborn as sns
import matplotlib.pyplot as plt
import matplotlib.image as mimg
import tensorflow as tf

# Import packages for data handling
import h5py
from PIL import Image
from skimage.io import imread
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import classification_report, confusion_matrix, roc_curve, auc
from mlxtend.plotting import plot_confusion_matrix

# Import deep learning package (tensorflow)
from tensorflow.keras.models import Sequential, Model
from tensorflow.keras.applications import mobilenet_v2
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Dense, Dropout, Input, Flatten, SeparableConv2D
from tensorflow.keras.layers import GlobalAveragePooling2D, BatchNormalization, Concatenate
from tensorflow.keras.optimizers import Adam, RMSprop
from tensorflow.keras.callbacks import ModelCheckpoint, TensorBoard, ReduceLROnPlateau
from tensorflow.keras.utils import to_categorical

color = sns.color_palette()
# %matplotlib inline

# Set seed nunmber to all packages
seed_number = 24
np.random.seed(seed_number)
tf.random.set_seed(seed_number)

# %%
# Configuring directories

# Input data files are available in the "../input/" directory.
# For example, running this (by clicking run or pressing Shift+Enter) will list the files in the input directory
root = "/content/"
input_dir = os.path.join(root,"output")
train_dir = os.path.join(input_dir, 'train')
val_dir = os.path.join(input_dir, 'val')
test_dir = os.path.join(input_dir, 'test')

dataset_dir = [dir for dir in sorted(os.listdir(input_dir)) if os.path.isdir(os.path.join(input_dir, dir))]
label_name = [subdir for subdir in sorted(os.listdir(train_dir)) if os.path.isdir(os.path.join(train_dir, subdir))]

# Printing the directory informations
print(f"Main directories\t: {os.listdir(root)}")
print(f"Dataset sub-directories\t: {dataset_dir}")
print(f"Train set directory\t: {label_name}")
# Out:
# Main directories	: ['.config', 'output', 'train', 'drive', 'sample_data']
# Dataset sub-directories	: ['test', 'train', 'val']
# Train set directory	: ['0', '1']

# %%
dir_dict = {'train': train_dir, 'val': val_dir, 'test': test_dir}
case_count, img_disp, set_length  = {}, {}, {}

for key, val in dir_dict.items():
    case_count[key] = {}
    img_disp[key] = {}
    set_count = 0
    
    for label in label_name:
        label_list = list(sorted(glob.glob(os.path.join(val, label, "*.jpg"))))
        if len(label_list) == 0:
          continue

        case_count[key][label] = len(label_list)
        set_count += len(label_list)
        
        select_img_id = np.random.randint(len(label_list)-1)
        # print(select_img_id)
        img_disp[key][label] = label_list[select_img_id]
        
    set_length[key] = set_count

case_count_df = pd.DataFrame(case_count)
img_disp_df = pd.DataFrame(img_disp)
print(f"Dataset summary:\n\n{case_count_df}")
# Out:
# Dataset summary:
#
#    train  val  test
# 0   2222  740   742
# 1   2373  791   791

# %%
# Visualizing some of the data set
num_classes = len(label_name)
num_dataset = 0
for key, val in set_length.items():
  num_dataset += 1 if val > 0 else 0

f, ax = plt.subplots(num_classes, num_dataset, figsize=(num_dataset*10, 18))

for k in range(num_classes*num_dataset):
    j, i = k//num_dataset, k%num_dataset  # Image indexing
    
    img = imread(img_disp_df.iloc[j, i])
    ax[j, i].imshow(img, cmap='gray')
    ax[j, i].set_title(f"{img_disp_df.columns[i].upper()}: {img_disp_df.index[j].capitalize()}", fontsize=32)
    ax[j, i].axis('off')
    ax[j, i].set_aspect('auto')
plt.show()

# %%
# Instantiate data generator for training procedure
train_datagen = ImageDataGenerator(rescale = 1./255,
                                   rotation_range = 20,
                                   width_shift_range = 0.2,
                                   height_shift_range = 0.2,
                                   shear_range = 0.15,
                                   zoom_range = 0.15,
                                   horizontal_flip = True,
                                   fill_mode="nearest")

val_datagen = ImageDataGenerator(rescale = 1./255)
test_datagen = ImageDataGenerator(rescale=1./255) if set_length["test"] > 0 else None

# %%
# Define dataset properties
train_batch_size = 32
val_batch_size = 32
img_width = 224
img_height = 224

# Generate dataset for train, val and test
train_gen = train_datagen.flow_from_directory(train_dir,
                                              batch_size = train_batch_size,
                                              class_mode = 'binary',
                                              target_size = (img_width, img_height),
                                              seed = seed_number)

val_gen = val_datagen.flow_from_directory(val_dir,
                                          batch_size = val_batch_size,
                                          class_mode = 'binary',
                                          target_size = (img_width, img_height),
                                          seed = seed_number)

if test_datagen is not None:
  test_gen = test_datagen.flow_from_directory(test_dir,
                                              batch_size = 1,
                                              class_mode = 'binary',
                                              target_size = (img_width, img_height),
                                              seed = seed_number,
                                              shuffle=False)
else:
  test_gen = None
# Out:
# Found 4595 images belonging to 2 classes.
# Found 1531 images belonging to 2 classes.
# Found 1533 images belonging to 2 classes.

# %%
# Displaying the dataset generator information
print(f'Train set batch shape\t: {next(train_gen)[0].shape}')
print(f'Val set batch shape\t: {next(val_gen)[0].shape}')
print(f'Test set batch shape\t: {next(test_gen)[0].shape}') if test_gen is not None else None
# Out:
# Train set batch shape	: (32, 224, 224, 3)
# Val set batch shape	: (32, 224, 224, 3)
# Test set batch shape	: (1, 224, 224, 3)

# %%
# Don't forget to turn on the Internet to download the respective pre-trained weights!
pretrain_net = mobilenet_v2.MobileNetV2(input_shape = (img_width, img_height, 3),
                                        include_top = False,
                                        weights = 'imagenet')


#load_param_path = '../input/mobilenet_v2/xception_weights_tf_dim_ordering_tf_kernels_notop.h5'  # Offline alternative
# pretrain_net.load_weights(load_param_path)  # Manually load the weights from the input directory

# ------ Freezing layer(s) up to a specific layer ------
freeze_before = None  #"block_16_expand"  # use None to train, use "all" to freeze all the layers

if freeze_before:
    for layer in pretrain_net.layers:
        if layer.name == freeze_before:
            break
        else:
            layer.trainable = False
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/mobilenet_v2/mobilenet_v2_weights_tf_dim_ordering_tf_kernels_1.0_224_no_top.h5
# 9406464/9406464 [==============================] - 0s 0us/step

# %%
# Adding extra layer for our problem
x = pretrain_net.output
x = Conv2D(32, (3, 3), activation='relu')(x)
x = Dropout(rate=0.2, name='extra_dropout1')(x)
x = GlobalAveragePooling2D()(x)
# x = Dense(units=128, activation='relu', name='extra_fc1')(x)
# x = Dropout(rate=0.2, name='extra_dropout1')(x)
x = Dense(1, activation='sigmoid', name='classifier')(x)

model = Model(inputs=pretrain_net.input, outputs=x, name='mobilenetv2_spoof')
print(model.summary())

# Notice: Unhide the OUTPUT!
# Out:
# Model: "mobilenetv2_spoof"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_1 (InputLayer)           [(None, 224, 224, 3  0           []
#                                 )]
#
#  Conv1 (Conv2D)                 (None, 112, 112, 32  864         ['input_1[0][0]']
#                                 )
#
#  bn_Conv1 (BatchNormalization)  (None, 112, 112, 32  128         ['Conv1[0][0]']
#                                 )
#
#  Conv1_relu (ReLU)              (None, 112, 112, 32  0           ['bn_Conv1[0][0]']
#                                 )
#
#  expanded_conv_depthwise (Depth  (None, 112, 112, 32  288        ['Conv1_relu[0][0]']
#  wiseConv2D)                    )
#
#  expanded_conv_depthwise_BN (Ba  (None, 112, 112, 32  128        ['expanded_conv_depthwise[0][0]']
#  tchNormalization)              )
#
#  expanded_conv_depthwise_relu (  (None, 112, 112, 32  0          ['expanded_conv_depthwise_BN[0][0
#  ReLU)                          )                                ]']
#
#  expanded_conv_project (Conv2D)  (None, 112, 112, 16  512        ['expanded_conv_depthwise_relu[0]
#                                 )                                [0]']
#
#  expanded_conv_project_BN (Batc  (None, 112, 112, 16  64         ['expanded_conv_project[0][0]']
#  hNormalization)                )
#
#  block_1_expand (Conv2D)        (None, 112, 112, 96  1536        ['expanded_conv_project_BN[0][0]'
#                                 )                                ]
#
#  block_1_expand_BN (BatchNormal  (None, 112, 112, 96  384        ['block_1_expand[0][0]']
#  ization)                       )
#
#  block_1_expand_relu (ReLU)     (None, 112, 112, 96  0           ['block_1_expand_BN[0][0]']
#                                 )
#
#  block_1_pad (ZeroPadding2D)    (None, 113, 113, 96  0           ['block_1_expand_relu[0][0]']
#                                 )
#
#  block_1_depthwise (DepthwiseCo  (None, 56, 56, 96)  864         ['block_1_pad[0][0]']
#  nv2D)
#
#  block_1_depthwise_BN (BatchNor  (None, 56, 56, 96)  384         ['block_1_depthwise[0][0]']
#  malization)
#
#  block_1_depthwise_relu (ReLU)  (None, 56, 56, 96)   0           ['block_1_depthwise_BN[0][0]']
#
#  block_1_project (Conv2D)       (None, 56, 56, 24)   2304        ['block_1_depthwise_relu[0][0]']
#
#  block_1_project_BN (BatchNorma  (None, 56, 56, 24)  96          ['block_1_project[0][0]']
#  lization)
#
#  block_2_expand (Conv2D)        (None, 56, 56, 144)  3456        ['block_1_project_BN[0][0]']
#
#  block_2_expand_BN (BatchNormal  (None, 56, 56, 144)  576        ['block_2_expand[0][0]']
#  ization)
#
#  block_2_expand_relu (ReLU)     (None, 56, 56, 144)  0           ['block_2_expand_BN[0][0]']
#
#  block_2_depthwise (DepthwiseCo  (None, 56, 56, 144)  1296       ['block_2_expand_relu[0][0]']
#  nv2D)
#
#  block_2_depthwise_BN (BatchNor  (None, 56, 56, 144)  576        ['block_2_depthwise[0][0]']
#  malization)
#
#  block_2_depthwise_relu (ReLU)  (None, 56, 56, 144)  0           ['block_2_depthwise_BN[0][0]']
#
#  block_2_project (Conv2D)       (None, 56, 56, 24)   3456        ['block_2_depthwise_relu[0][0]']
#
#  block_2_project_BN (BatchNorma  (None, 56, 56, 24)  96          ['block_2_project[0][0]']
#  lization)
#
#  block_2_add (Add)              (None, 56, 56, 24)   0           ['block_1_project_BN[0][0]',
#                                                                   'block_2_project_BN[0][0]']
#
#  block_3_expand (Conv2D)        (None, 56, 56, 144)  3456        ['block_2_add[0][0]']
#
#  block_3_expand_BN (BatchNormal  (None, 56, 56, 144)  576        ['block_3_expand[0][0]']
#  ization)
#
#  block_3_expand_relu (ReLU)     (None, 56, 56, 144)  0           ['block_3_expand_BN[0][0]']
#
#  block_3_pad (ZeroPadding2D)    (None, 57, 57, 144)  0           ['block_3_expand_relu[0][0]']
#
#  block_3_depthwise (DepthwiseCo  (None, 28, 28, 144)  1296       ['block_3_pad[0][0]']
#  nv2D)
#
#  block_3_depthwise_BN (BatchNor  (None, 28, 28, 144)  576        ['block_3_depthwise[0][0]']
#  malization)
#
#  block_3_depthwise_relu (ReLU)  (None, 28, 28, 144)  0           ['block_3_depthwise_BN[0][0]']
#
#  block_3_project (Conv2D)       (None, 28, 28, 32)   4608        ['block_3_depthwise_relu[0][0]']
#
#  block_3_project_BN (BatchNorma  (None, 28, 28, 32)  128         ['block_3_project[0][0]']
#  lization)
#
#  block_4_expand (Conv2D)        (None, 28, 28, 192)  6144        ['block_3_project_BN[0][0]']
#
#  block_4_expand_BN (BatchNormal  (None, 28, 28, 192)  768        ['block_4_expand[0][0]']
#  ization)
#
#  block_4_expand_relu (ReLU)     (None, 28, 28, 192)  0           ['block_4_expand_BN[0][0]']
#
#  block_4_depthwise (DepthwiseCo  (None, 28, 28, 192)  1728       ['block_4_expand_relu[0][0]']
#  nv2D)
#
#  block_4_depthwise_BN (BatchNor  (None, 28, 28, 192)  768        ['block_4_depthwise[0][0]']
#  malization)
#
#  block_4_depthwise_relu (ReLU)  (None, 28, 28, 192)  0           ['block_4_depthwise_BN[0][0]']
#
#  block_4_project (Conv2D)       (None, 28, 28, 32)   6144        ['block_4_depthwise_relu[0][0]']
#
#  block_4_project_BN (BatchNorma  (None, 28, 28, 32)  128         ['block_4_project[0][0]']
#  lization)
#
#  block_4_add (Add)              (None, 28, 28, 32)   0           ['block_3_project_BN[0][0]',
#                                                                   'block_4_project_BN[0][0]']
#
#  block_5_expand (Conv2D)        (None, 28, 28, 192)  6144        ['block_4_add[0][0]']
#
#  block_5_expand_BN (BatchNormal  (None, 28, 28, 192)  768        ['block_5_expand[0][0]']
#  ization)
#
#  block_5_expand_relu (ReLU)     (None, 28, 28, 192)  0           ['block_5_expand_BN[0][0]']
#
#  block_5_depthwise (DepthwiseCo  (None, 28, 28, 192)  1728       ['block_5_expand_relu[0][0]']
#  nv2D)
#
#  block_5_depthwise_BN (BatchNor  (None, 28, 28, 192)  768        ['block_5_depthwise[0][0]']
#  malization)
#
#  block_5_depthwise_relu (ReLU)  (None, 28, 28, 192)  0           ['block_5_depthwise_BN[0][0]']
#
#  block_5_project (Conv2D)       (None, 28, 28, 32)   6144        ['block_5_depthwise_relu[0][0]']
#
#  block_5_project_BN (BatchNorma  (None, 28, 28, 32)  128         ['block_5_project[0][0]']
#  lization)
#
#  block_5_add (Add)              (None, 28, 28, 32)   0           ['block_4_add[0][0]',
#                                                                   'block_5_project_BN[0][0]']
#
#  block_6_expand (Conv2D)        (None, 28, 28, 192)  6144        ['block_5_add[0][0]']
#
#  block_6_expand_BN (BatchNormal  (None, 28, 28, 192)  768        ['block_6_expand[0][0]']
#  ization)
#
#  block_6_expand_relu (ReLU)     (None, 28, 28, 192)  0           ['block_6_expand_BN[0][0]']
#
#  block_6_pad (ZeroPadding2D)    (None, 29, 29, 192)  0           ['block_6_expand_relu[0][0]']
#
#  block_6_depthwise (DepthwiseCo  (None, 14, 14, 192)  1728       ['block_6_pad[0][0]']
#  nv2D)
#
#  block_6_depthwise_BN (BatchNor  (None, 14, 14, 192)  768        ['block_6_depthwise[0][0]']
#  malization)
#
#  block_6_depthwise_relu (ReLU)  (None, 14, 14, 192)  0           ['block_6_depthwise_BN[0][0]']
#
#  block_6_project (Conv2D)       (None, 14, 14, 64)   12288       ['block_6_depthwise_relu[0][0]']
#
#  block_6_project_BN (BatchNorma  (None, 14, 14, 64)  256         ['block_6_project[0][0]']
#  lization)
#
#  block_7_expand (Conv2D)        (None, 14, 14, 384)  24576       ['block_6_project_BN[0][0]']
#
#  block_7_expand_BN (BatchNormal  (None, 14, 14, 384)  1536       ['block_7_expand[0][0]']
#  ization)
#
#  block_7_expand_relu (ReLU)     (None, 14, 14, 384)  0           ['block_7_expand_BN[0][0]']
#
#  block_7_depthwise (DepthwiseCo  (None, 14, 14, 384)  3456       ['block_7_expand_relu[0][0]']
#  nv2D)
#
#  block_7_depthwise_BN (BatchNor  (None, 14, 14, 384)  1536       ['block_7_depthwise[0][0]']
#  malization)
#
#  block_7_depthwise_relu (ReLU)  (None, 14, 14, 384)  0           ['block_7_depthwise_BN[0][0]']
#
#  block_7_project (Conv2D)       (None, 14, 14, 64)   24576       ['block_7_depthwise_relu[0][0]']
#
#  block_7_project_BN (BatchNorma  (None, 14, 14, 64)  256         ['block_7_project[0][0]']
#  lization)
#
#  block_7_add (Add)              (None, 14, 14, 64)   0           ['block_6_project_BN[0][0]',
#                                                                   'block_7_project_BN[0][0]']
#
#  block_8_expand (Conv2D)        (None, 14, 14, 384)  24576       ['block_7_add[0][0]']
#
#  block_8_expand_BN (BatchNormal  (None, 14, 14, 384)  1536       ['block_8_expand[0][0]']
#  ization)
#
#  block_8_expand_relu (ReLU)     (None, 14, 14, 384)  0           ['block_8_expand_BN[0][0]']
#
#  block_8_depthwise (DepthwiseCo  (None, 14, 14, 384)  3456       ['block_8_expand_relu[0][0]']
#  nv2D)
#
#  block_8_depthwise_BN (BatchNor  (None, 14, 14, 384)  1536       ['block_8_depthwise[0][0]']
#  malization)
#
#  block_8_depthwise_relu (ReLU)  (None, 14, 14, 384)  0           ['block_8_depthwise_BN[0][0]']
#
#  block_8_project (Conv2D)       (None, 14, 14, 64)   24576       ['block_8_depthwise_relu[0][0]']
#
#  block_8_project_BN (BatchNorma  (None, 14, 14, 64)  256         ['block_8_project[0][0]']
#  lization)
#
#  block_8_add (Add)              (None, 14, 14, 64)   0           ['block_7_add[0][0]',
#                                                                   'block_8_project_BN[0][0]']
#
#  block_9_expand (Conv2D)        (None, 14, 14, 384)  24576       ['block_8_add[0][0]']
#
#  block_9_expand_BN (BatchNormal  (None, 14, 14, 384)  1536       ['block_9_expand[0][0]']
#  ization)
#
#  block_9_expand_relu (ReLU)     (None, 14, 14, 384)  0           ['block_9_expand_BN[0][0]']
#
#  block_9_depthwise (DepthwiseCo  (None, 14, 14, 384)  3456       ['block_9_expand_relu[0][0]']
#  nv2D)
#
#  block_9_depthwise_BN (BatchNor  (None, 14, 14, 384)  1536       ['block_9_depthwise[0][0]']
#  malization)
#
#  block_9_depthwise_relu (ReLU)  (None, 14, 14, 384)  0           ['block_9_depthwise_BN[0][0]']
#
#  block_9_project (Conv2D)       (None, 14, 14, 64)   24576       ['block_9_depthwise_relu[0][0]']
#
#  block_9_project_BN (BatchNorma  (None, 14, 14, 64)  256         ['block_9_project[0][0]']
#  lization)
#
#  block_9_add (Add)              (None, 14, 14, 64)   0           ['block_8_add[0][0]',
#                                                                   'block_9_project_BN[0][0]']
#
#  block_10_expand (Conv2D)       (None, 14, 14, 384)  24576       ['block_9_add[0][0]']
#
#  block_10_expand_BN (BatchNorma  (None, 14, 14, 384)  1536       ['block_10_expand[0][0]']
#  lization)
#
#  block_10_expand_relu (ReLU)    (None, 14, 14, 384)  0           ['block_10_expand_BN[0][0]']
#
#  block_10_depthwise (DepthwiseC  (None, 14, 14, 384)  3456       ['block_10_expand_relu[0][0]']
#  onv2D)
#
#  block_10_depthwise_BN (BatchNo  (None, 14, 14, 384)  1536       ['block_10_depthwise[0][0]']
#  rmalization)
#
#  block_10_depthwise_relu (ReLU)  (None, 14, 14, 384)  0          ['block_10_depthwise_BN[0][0]']
#
#  block_10_project (Conv2D)      (None, 14, 14, 96)   36864       ['block_10_depthwise_relu[0][0]']
#
#  block_10_project_BN (BatchNorm  (None, 14, 14, 96)  384         ['block_10_project[0][0]']
#  alization)
#
#  block_11_expand (Conv2D)       (None, 14, 14, 576)  55296       ['block_10_project_BN[0][0]']
#
#  block_11_expand_BN (BatchNorma  (None, 14, 14, 576)  2304       ['block_11_expand[0][0]']
#  lization)
#
#  block_11_expand_relu (ReLU)    (None, 14, 14, 576)  0           ['block_11_expand_BN[0][0]']
#
#  block_11_depthwise (DepthwiseC  (None, 14, 14, 576)  5184       ['block_11_expand_relu[0][0]']
#  onv2D)
#
#  block_11_depthwise_BN (BatchNo  (None, 14, 14, 576)  2304       ['block_11_depthwise[0][0]']
#  rmalization)
#
#  block_11_depthwise_relu (ReLU)  (None, 14, 14, 576)  0          ['block_11_depthwise_BN[0][0]']
#
#  block_11_project (Conv2D)      (None, 14, 14, 96)   55296       ['block_11_depthwise_relu[0][0]']
#
#  block_11_project_BN (BatchNorm  (None, 14, 14, 96)  384         ['block_11_project[0][0]']
#  alization)
#
#  block_11_add (Add)             (None, 14, 14, 96)   0           ['block_10_project_BN[0][0]',
#                                                                   'block_11_project_BN[0][0]']
#
#  block_12_expand (Conv2D)       (None, 14, 14, 576)  55296       ['block_11_add[0][0]']
#
#  block_12_expand_BN (BatchNorma  (None, 14, 14, 576)  2304       ['block_12_expand[0][0]']
#  lization)
#
#  block_12_expand_relu (ReLU)    (None, 14, 14, 576)  0           ['block_12_expand_BN[0][0]']
#
#  block_12_depthwise (DepthwiseC  (None, 14, 14, 576)  5184       ['block_12_expand_relu[0][0]']
#  onv2D)
#
#  block_12_depthwise_BN (BatchNo  (None, 14, 14, 576)  2304       ['block_12_depthwise[0][0]']
#  rmalization)
#
#  block_12_depthwise_relu (ReLU)  (None, 14, 14, 576)  0          ['block_12_depthwise_BN[0][0]']
#
#  block_12_project (Conv2D)      (None, 14, 14, 96)   55296       ['block_12_depthwise_relu[0][0]']
#
#  block_12_project_BN (BatchNorm  (None, 14, 14, 96)  384         ['block_12_project[0][0]']
#  alization)
#
#  block_12_add (Add)             (None, 14, 14, 96)   0           ['block_11_add[0][0]',
#                                                                   'block_12_project_BN[0][0]']
#
#  block_13_expand (Conv2D)       (None, 14, 14, 576)  55296       ['block_12_add[0][0]']
#
#  block_13_expand_BN (BatchNorma  (None, 14, 14, 576)  2304       ['block_13_expand[0][0]']
#  lization)
#
#  block_13_expand_relu (ReLU)    (None, 14, 14, 576)  0           ['block_13_expand_BN[0][0]']
#
#  block_13_pad (ZeroPadding2D)   (None, 15, 15, 576)  0           ['block_13_expand_relu[0][0]']
#
#  block_13_depthwise (DepthwiseC  (None, 7, 7, 576)   5184        ['block_13_pad[0][0]']
#  onv2D)
#
#  block_13_depthwise_BN (BatchNo  (None, 7, 7, 576)   2304        ['block_13_depthwise[0][0]']
#  rmalization)
#
#  block_13_depthwise_relu (ReLU)  (None, 7, 7, 576)   0           ['block_13_depthwise_BN[0][0]']
#
#  block_13_project (Conv2D)      (None, 7, 7, 160)    92160       ['block_13_depthwise_relu[0][0]']
#
#  block_13_project_BN (BatchNorm  (None, 7, 7, 160)   640         ['block_13_project[0][0]']
#  alization)
#
#  block_14_expand (Conv2D)       (None, 7, 7, 960)    153600      ['block_13_project_BN[0][0]']
#
#  block_14_expand_BN (BatchNorma  (None, 7, 7, 960)   3840        ['block_14_expand[0][0]']
#  lization)
#
#  block_14_expand_relu (ReLU)    (None, 7, 7, 960)    0           ['block_14_expand_BN[0][0]']
#
#  block_14_depthwise (DepthwiseC  (None, 7, 7, 960)   8640        ['block_14_expand_relu[0][0]']
#  onv2D)
#
#  block_14_depthwise_BN (BatchNo  (None, 7, 7, 960)   3840        ['block_14_depthwise[0][0]']
#  rmalization)
#
#  block_14_depthwise_relu (ReLU)  (None, 7, 7, 960)   0           ['block_14_depthwise_BN[0][0]']
#
#  block_14_project (Conv2D)      (None, 7, 7, 160)    153600      ['block_14_depthwise_relu[0][0]']
#
#  block_14_project_BN (BatchNorm  (None, 7, 7, 160)   640         ['block_14_project[0][0]']
#  alization)
#
#  block_14_add (Add)             (None, 7, 7, 160)    0           ['block_13_project_BN[0][0]',
#                                                                   'block_14_project_BN[0][0]']
#
#  block_15_expand (Conv2D)       (None, 7, 7, 960)    153600      ['block_14_add[0][0]']
#
#  block_15_expand_BN (BatchNorma  (None, 7, 7, 960)   3840        ['block_15_expand[0][0]']
#  lization)
#
#  block_15_expand_relu (ReLU)    (None, 7, 7, 960)    0           ['block_15_expand_BN[0][0]']
#
#  block_15_depthwise (DepthwiseC  (None, 7, 7, 960)   8640        ['block_15_expand_relu[0][0]']
#  onv2D)
#
#  block_15_depthwise_BN (BatchNo  (None, 7, 7, 960)   3840        ['block_15_depthwise[0][0]']
#  rmalization)
#
#  block_15_depthwise_relu (ReLU)  (None, 7, 7, 960)   0           ['block_15_depthwise_BN[0][0]']
#
#  block_15_project (Conv2D)      (None, 7, 7, 160)    153600      ['block_15_depthwise_relu[0][0]']
#
#  block_15_project_BN (BatchNorm  (None, 7, 7, 160)   640         ['block_15_project[0][0]']
#  alization)
#
#  block_15_add (Add)             (None, 7, 7, 160)    0           ['block_14_add[0][0]',
#                                                                   'block_15_project_BN[0][0]']
#
#  block_16_expand (Conv2D)       (None, 7, 7, 960)    153600      ['block_15_add[0][0]']
#
#  block_16_expand_BN (BatchNorma  (None, 7, 7, 960)   3840        ['block_16_expand[0][0]']
#  lization)
#
#  block_16_expand_relu (ReLU)    (None, 7, 7, 960)    0           ['block_16_expand_BN[0][0]']
#
#  block_16_depthwise (DepthwiseC  (None, 7, 7, 960)   8640        ['block_16_expand_relu[0][0]']
#  onv2D)
#
#  block_16_depthwise_BN (BatchNo  (None, 7, 7, 960)   3840        ['block_16_depthwise[0][0]']
#  rmalization)
#
#  block_16_depthwise_relu (ReLU)  (None, 7, 7, 960)   0           ['block_16_depthwise_BN[0][0]']
#
#  block_16_project (Conv2D)      (None, 7, 7, 320)    307200      ['block_16_depthwise_relu[0][0]']
#
#  block_16_project_BN (BatchNorm  (None, 7, 7, 320)   1280        ['block_16_project[0][0]']
#  alization)
#
#  Conv_1 (Conv2D)                (None, 7, 7, 1280)   409600      ['block_16_project_BN[0][0]']
#
#  Conv_1_bn (BatchNormalization)  (None, 7, 7, 1280)  5120        ['Conv_1[0][0]']
#
#  out_relu (ReLU)                (None, 7, 7, 1280)   0           ['Conv_1_bn[0][0]']
#
#  conv2d (Conv2D)                (None, 5, 5, 32)     368672      ['out_relu[0][0]']
#
#  extra_dropout1 (Dropout)       (None, 5, 5, 32)     0           ['conv2d[0][0]']
#
#  global_average_pooling2d (Glob  (None, 32)          0           ['extra_dropout1[0][0]']
#  alAveragePooling2D)
#
#  classifier (Dense)             (None, 1)            33          ['global_average_pooling2d[0][0]'
#                                                                  ]
#
# ==================================================================================================
# Total params: 2,626,689
# Trainable params: 2,592,577
# Non-trainable params: 34,112
# __________________________________________________________________________________________________
# None

# %%
train_id = "lcc-train04b-weight_all_2"  # ID of the training procedure
num_epochs = 20  # Set the number of epochs to train
learning_rate = 5e-5  # Set the learning rate to use

print(f"Training config of '{train_id}'...")
print(f"Number of epoch\t: {num_epochs}")
print(f"Initial LR\t: {learning_rate}")

model.compile(optimizer = Adam(lr=learning_rate),
              loss = 'binary_crossentropy',
              metrics = ['acc'])

# Define model callback
save_dir = os.path.join("./", train_id)
if not os.path.isdir(save_dir):
  os.makedirs(save_dir)

cont_filepath = "mobilenetv2-epoch_{epoch:02d}.hdf5"
cont_checkpoint = ModelCheckpoint(os.path.join(save_dir, cont_filepath))

best_filepath = "mobilenetv2-best.hdf5"
best_checkpoint = ModelCheckpoint(os.path.join(save_dir, best_filepath),
                                  save_best_only=True,
                                  save_weights_only=True)

# Instantiate tensorboard
log_dir = os.path.join(save_dir, "logs")
use_tensorboard = TensorBoard(log_dir=log_dir,
                              histogram_freq=1,
                              update_freq="batch")

# Instantiate learning rate scheduler with Plateau method
plateau_scheduler = ReduceLROnPlateau(factor=0.2, patience=3, verbose=1, 
                                      min_delta= 0.005, min_lr=5e-7)

# Displaying tensorboard
#%tensorboard --logdir log_dir

# Define class weight
train_length = len(train_gen.classes)
weight0 = train_length / case_count_df['train'][label_name[0]] * (1 / len(label_name))
weight1 = train_length / case_count_df['train'][label_name[1]] * (1 / len(label_name))
class_weight = {0: weight0, 1: weight1}

print(f"Class weight\t: {class_weight}")
# Out:
# Training config of 'lcc-train04b-weight_all_2'...
# Number of epoch	: 20
# Initial LR	: 5e-05
# Class weight	: {0: 1.033978397839784, 1: 0.9681837336704593}
# /usr/local/lib/python3.7/dist-packages/keras/optimizers/optimizer_v2/adam.py:110: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   super(Adam, self).__init__(name, **kwargs)

# %%
# Resume training (UNCOMMENT to use!)
# checkpoint_path = "mobilenetv2-epoch_01"
# model.load(os.path.join(savedir, checkpoint_path))

# Perform training
history = model.fit(train_gen,
                    epochs = num_epochs,
                    steps_per_epoch = set_length['train'] // train_batch_size,
                    validation_data = val_gen,
                    validation_steps = 1,
                    callbacks = [best_checkpoint,
                                 cont_checkpoint,
                                 plateau_scheduler],
                    class_weight=class_weight)

history_df = pd.DataFrame.from_dict(history.history)
history_df.to_csv(os.path.join(save_dir, "history.csv"), index=False)

# Notice: Unhide the OUTPUT!
# Out:
# Epoch 1/20
#  73/143 [==============>...............] - ETA: 9:00 - loss: 0.4063 - acc: 0.8108

# %%
# Plotting the train results
train_accuracy = history.history['acc']
val_accuracy = history.history['val_acc']
train_loss = history.history['loss']
val_loss = history.history['val_loss']

epochs = range(len(train_accuracy))
plt.figure(figsize=(12,4))

# Plotting the accuracy
plt.subplot(1,2,1)
plt.plot(epochs, train_accuracy, 'b', label='Training accuracy')
plt.plot(epochs, val_accuracy, 'r', label='Validation accuracy')
plt.title('Training and validation accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.legend(['train', 'val'], loc='lower right')

# Plotting the loss
plt.subplot(1,2,2)
plt.plot(epochs, train_loss, 'b', label='Training loss')
plt.plot(epochs, val_loss, 'r', label='Validation loss')
plt.title('Training and validation loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend(['train', 'val'], loc='upper right')

plt.show()

# %%
# Test set accuracy and loss
test_scores = model.evaluate(test_gen, steps=set_length['test'])
print("Test results Accuracy: {0:.2f}% and Loss: {0:.2f}".format(test_scores[1]*100, test_scores[0]))

# Calculate prediction

threshold = 0.5  # Define the sigmoid threshold for True or False
y_pred_value = np.squeeze(model.predict(test_gen, steps=set_length['test'], verbose=1))

y_pred = np.zeros(y_pred_value.shape).astype(np.int32)  # Sigmoid
y_pred[y_pred_value > threshold] = 1

# y_pred = np.argmax(y_pred_value, axis=-1).astype(np.int32)  # Softmax

y_true = test_gen.classes

# Sanity check on the y_pred and y_true value
print(f"Label\t\t: {y_true[:10]}")
print(f"Prediction\t: {y_pred[:10]}")

# %%
# Confusion matrix result
confusion_matrix_result = confusion_matrix(y_true, y_pred)
plot_confusion_matrix(confusion_matrix_result,
                      figsize=(12,8),
                      hide_ticks=True,
                      cmap=plt.cm.jet)
plt.title("Face Spoofing Detection")
plt.xticks(range(2), ['Real', 'Spoof'], fontsize=16)
plt.yticks(range(2), ['Real', 'Spoof'], fontsize=16)
plt.show()

# Precision and Recall metrics
tn, fp, fn, tp = confusion_matrix_result.ravel()
precision = tp / (tp+fp)
recall = tp / (tp+fn)
f1_score = 2 * precision * recall / (precision+recall)

print("Report Summary:")
print("Precision\t: {:.2f}%".format(precision*100))
print("Recall\t\t: {:.2f}%".format(recall*100))
print("F1 Score\t: {:.2f}%".format(f1_score*100))

print("\nNotes: ")
print("True labels\t: Spoof")
print("False labels\t: Real")

# %%
pred_value = model.predict(test_gen, steps=set_length['test'], verbose=1)

# %%
pred_value[:10]

# %%
y_true

# %%
wrong_predictions = [y_pred != y_true]

# %%
(wrong_predictions[0] == True).sum()

# %%
# !mkdirs public_test
! unzip "/content/drive/MyDrive/data (1)/test_data.zip" -d public_test

# %%
y!zip -r '/content/lcc-train04b-weight_all.zip' '/content/lcc-train04b-weight_all'

# %%
from google.colab import files
files.download("/content/lcc-train04b-weight_all.zip")
